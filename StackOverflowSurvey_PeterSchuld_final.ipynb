# %% [markdown]
# ![title](https://stackoverflow.design/assets/img/logos/so/logo-stackoverflow.png)
#
# # Annual Developer Survey
# ## by Peter H. Schuld
#
# ## Jan, 2020

# %% [markdown]
# #### Data Description
#
# Since 2011, Stack Overflow, a popular Q&A site for developers, has surveyed a large number of users. The annual surveys consist of questions with numerical answers (e.g. age, salary) and of questions with categorical answers from multiple choice options ( "choose one" or "choose all that apply" ). With nearly 65,000 responses fielded from over 180 countries and dependent territories, the 2020 Annual Developer Survey examines different aspects of the developer experience from career satisfaction and job search to education and opinions on open source software.
#
# Founded in 2008, Stack Overflow’s public platform is used by nearly everyone who codes to learn, share their knowledge, collaborate, and build their careers. For almost a decade, Stack Overflow’s annual Developer Survey has been the largest survey of people who code around the world.
#
# Notably, the 2020 survey was conducted in February, before the World Health Organization declared the coronavirus outbreak to be a pandemic.

# %% [markdown]
# #### Summary
#
#
# We use the 2018 and 2020 developer surveys to analyse changes in the popularity of programming languages. Two of the survey questions are asking about programming languages users have done extensive development work in over the past year, and which languages they want to work in over the next year.
#
# We use the 2020 survey to analyse correlations between programming languages and between other frameworks, libraries, and tools (i.e. technologies) users have done extensive development work in over the past year. Furthermore, we filter the data for respondants who perform the developer role of *Data Scientist or Machine Learning Specialist*. We analyse what additional developer roles they perform, what languages they prefer and what technologies they use.
#
# Finally, we use a linear machine learning model to find coefficients with significant impact on the salaries of professional developers in the United States.

# %% [markdown]
# ## Table of Contents
# I. [**Preliminary Data Wrangling**](#wrangling)
# - [Calculating permutations for multiple choice questions and responses](#permutations)
#
# II. [**What is the structure of the dataset?**](#structure)
#
# III. [**Exploration of numerical variables**](#numerical)
# - [What is the distribution of salaries](#question0)
#
# IV. [**Exploration of categorical variables**](#categorical)
# - [Which Project Management Methodologies Do Developers Use?](#methodology)
# - [What additional developer roles do Data Scientist/Machine_Learning_specialist perform ?](#question1)
# - [What programming languages do Data Scientist/Machine Learning Specialist use ?](#question2)
# - [What is the correlation between technologies ?](#question3)
# - [What technologies do Data Scientist/Machine Learning Specialist use ?](#question4)
# - [What is the correlation between languages ?](#question5)
#
# V. [**Intertemporal exploration**](#intertemporal)
# - [What languages are gaining popularity ?](#question6)
#
# VI. [**Machine learning**](#ml)
#
# - [What variables have a strong impact on the salaries of professional software developers in the USA ?](#question7)
#
# VII. [**Conclusion**](#Conclusion)

# %% [markdown]
# <a id='wrangling'></a>
# # Preliminary Wrangling

# %% [markdown]
# We load all the necessary libraries.

# %%
# import all packages and set plots to be embedded inline                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
#import AllTogether as t
import seaborn as sns
# %matplotlib inline
from itertools import chain

# %% [markdown]
# ## Gathering Data

# %% [markdown]
# We load the datasets for the Developer Surveys 2018 and 2020 into a pandas dataframe and print statistics.

# %%
# load the .csv file from the current directory
df2018 = pd.read_csv('./survey_results_public2018.csv')
df2020 = pd.read_csv('./survey_results_public2020.csv')
df2020.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
# ...

# %%
# high-level overview of data shape and composition
print(df2018.shape)
# Out:
# (98855, 129)

# %%
# high-level overview of data shape and composition
print(df2020.shape)
# Out:
# (64461, 61)

# %% [markdown]
# We have successfully gathered the data. Next, we will be analysing the data.

# %% [markdown]
# ## Assessing Data##
#
# ➔ Assess data visually and programmatically using pandas
#
# ➔ Distinguish between dirty data (content or “quality” issues) and
# messy data (structural or “tidiness” issues)
#
# ➔ Identify data quality issues and categorize them using metrics:
# validity, accuracy, completeness, and consistency
#
#
#
# You can assess data for:
# - ***QUALITY:*** issues with content. Low quality data is also known as dirty data.
#   (e.g. inaccurate data, corrupted data, duplicate data)
# - ***TIDINESS:*** issues with structure that prevent easy analysis. Untidy data is also known as messy data.
#
# ***QUALITY dimensions: (the four main)***
#
# - ***Completeness:*** do we have all of the records that we should? Do we have missing records or not? Are there specific rows, columns, or cells missing?
# - ***Validity:*** we have the records, but they're not valid, i.e., they don't conform to a defined schema. A schema is a defined set of rules for data. These rules can be real-world constraints (e.g. negative height is impossible) and table-specific constraints (e.g. unique key constraints in tables).
# - ***Accuracy:*** inaccurate data is wrong data that is valid. It adheres to the defined schema, but it is still incorrect. Example: a patient's weight that is 5 lbs too heavy because the scale was faulty.
# - ***Consistency:*** inconsistent data is both valid and accurate, but there are multiple correct ways of referring to the same thing. Consistency, i.e., a standard format, in columns that represent the same data across tables and/or within tables is desired.
#
#
# ***TIDINESS requires:***
#
# * Each variable forms a column.
# * Each observation forms a row.
# * Each type of observational unit forms a table.

# %%
df2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98855 entries, 0 to 98854
# Columns: 129 entries, Respondent to SurveyEasy
# dtypes: float64(41), int64(1), object(87)
# memory usage: 97.3+ MB

# %% [markdown]
# The Developer Survey 2018 **`df2018`** contains 129 variables (columns) with 98855 observations (rows). There are 42 numeric variables and 87 variables are categorical (i.e. type = object).

# %%
df2018.hist(); # show histograms or all the numerical variables

# %% [markdown]
# We will only be using a limited number of the variables from the 2018 Survey going forward because we will be using the most recent data.

# %%
df2020.hist(); # show histograms or all the numerical variables

# %% [markdown]
# The Developer Survey 2020 **`df2020`**  contains 61 variables (columns) with 64460 observations (rows). There are 5 numeric variables and 56 variables are categorical (i.e. type = object).

# %%
df2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 61 columns):
# Respondent                      64461 non-null int64
# MainBranch                      64162 non-null object
# Hobbyist                        64416 non-null object
# Age                             45446 non-null float64
# Age1stCode                      57900 non-null object
# CompFreq                        40069 non-null object
# CompTotal                       34826 non-null float64
# ConvertedComp                   34756 non-null float64
# Country                         64072 non-null object
# CurrencyDesc                    45472 non-null object
# CurrencySymbol                  45472 non-null object
# DatabaseDesireNextYear          44070 non-null object
# DatabaseWorkedWith              49537 non-null object
# DevType                         49370 non-null object
# EdLevel                         57431 non-null object
# ...

# %%
df2018.nunique() #  show no. of unique entries in each column
# Out:
# Respondent                     98855
# Hobby                              2
# OpenSource                         2
# Country                          183
# Student                            3
# Employment                         6
# FormalEducation                    9
# UndergradMajor                    12
# CompanySize                        8
# DevType                         9568
# YearsCoding                       11
# YearsCodingProf                   11
# JobSatisfaction                    7
# CareerSatisfaction                 7
# HopeFiveYears                      7
# JobSearchStatus                    3
# LastNewJob                         5
# AssessJob1                        10
# AssessJob2                        10
# AssessJob3                        10
# AssessJob4                        10
# AssessJob5                        10
# AssessJob6                        10
# AssessJob7                        10
# AssessJob8                        10
# ...

# %% [markdown]
# In the Developer Survey 2018 **`df2018`** most of the 129 ``variables`` have a limited number of unique entries. Presumably, the multiple choice questions for the categorical variables only allow **one answer each**.
#
# However, the variable `DevType` has a large number of unique entries, because most respondants stated multiple developer roles.

# %%
df2018.groupby('DevType').mean()
# Out:
#                                                        Respondent  AssessJob1  \
# DevType
# Back-end developer                                   51735.591242    6.644076
# Back-end developer;C-suite executive (CEO, CTO,...   50857.935897    5.980000
# Back-end developer;C-suite executive (CEO, CTO,...   24350.800000    4.750000
# Back-end developer;C-suite executive (CEO, CTO,...   25305.000000    6.000000
# Back-end developer;C-suite executive (CEO, CTO,...   42108.000000         NaN
# Back-end developer;C-suite executive (CEO, CTO,...   12922.000000         NaN
# Back-end developer;C-suite executive (CEO, CTO,...   54768.727273    5.250000
# Back-end developer;C-suite executive (CEO, CTO,...   78173.000000    2.000000
# Back-end developer;C-suite executive (CEO, CTO,...   50959.000000    9.000000
# Back-end developer;C-suite executive (CEO, CTO,...    4089.000000    7.000000
# Back-end developer;C-suite executive (CEO, CTO,...   72380.000000    2.000000
# ...

# %% [markdown]
# Let us look at the number of unique entries for the 61 variables of the Survey 2020 **`df2020`** .

# %%
df2020.nunique() #  show no. of unique entries in each column
# Out:
# Respondent                      64461
# MainBranch                          5
# Hobbyist                            2
# Age                               110
# Age1stCode                         63
# CompFreq                            3
# CompTotal                        3003
# ConvertedComp                    6958
# Country                           183
# CurrencyDesc                      142
# CurrencySymbol                    141
# DatabaseDesireNextYear           3193
# DatabaseWorkedWith               2808
# DevType                          8269
# EdLevel                             9
# Employment                          7
# Ethnicity                         208
# Gender                              7
# JobFactors                        230
# JobSat                              5
# JobSeek                             3
# LanguageDesireNextYear          16243
# LanguageWorkedWith              14256
# MiscTechDesireNextYear           5216
# MiscTechWorkedWith               2730
# ...

# %% [markdown]
# <a id='permutations'></a>
#
# ## Calculating permutations for multiple choice questions and responses :
#
# The survey 2020 **`df2020`** has a smaller number of variables than the survey 2018 **`df2018`** . Many of the variables in **`df2020`** have a high number of unique entries, presumably because the respondants can choose more than one answer </font><font color='blue'> **(i.e. choose all that apply)**:<br></font><font color='black'>.
#
# However, the number of possible combinations rises exponentially with the number of options to choose from. If there are ***'n'*** binary options you can tick (checked box or blank box), than there are:
#
# \begin{equation}
# No. of combinations = 2^n - 1
# \end{equation}
#
# possible answers (i.e. unique entries). The −1 is the option where all fields are left blank, which we want to excluse.
#
#
#
# >For example, the variable **`df2020`** `Gender` has 7 unique entries, build from different combinations of the three
# >binary options ***``Man``***  ,  ***``Woman``***  and  ***``Non-binary, genderqueer, or gender non-conforming``*** .
# >
# >In this example, all the possible combinations can be calculated:
# >2 * 2 * 2 - 1 = 7
#
# https://math.stackexchange.com/questions/3282038/calculating-permutations-for-multiple-questions-and-responses

# %%
df2020.groupby('Gender').mean()
# Out:
#                                                       Respondent        Age  \
# Gender
# Man                                                 28970.066394  30.905800
# Man;Non-binary, genderqueer, or gender non-conf...  32648.719008  29.574074
# Non-binary, genderqueer, or gender non-conforming   31202.314286  28.842342
# Woman                                               31963.561134  30.139910
# Woman;Man                                           30037.881579  25.520833
# Woman;Man;Non-binary, genderqueer, or gender no...  27786.961538  41.357143
# Woman;Non-binary, genderqueer, or gender non-co...  33931.543478  27.345238
#
#                                                        CompTotal  \
# Gender
# Man                                                 3.414358e+08
# Man;Non-binary, genderqueer, or gender non-conf...  1.813509e+05
# Non-binary, genderqueer, or gender non-conforming   3.668910e+28
# Woman                                               5.675897e+05
# ...

# %% [markdown]
# In contrast, the number of possible combinations (i.e. unique entries) is lower when only one or a certain number of options can be selected.
#
# We can calculate the number of possible combinations of choosing x options out of n possible answers (i.e. n choose x):
#
# \begin{equation}
# No. of combinations = {n \choose x}
# \end{equation}
#
# When only one option can be choosen </font><font color='blue'> **(i.e. choose one)**:<br></font><font color='black'>
#
# \begin{equation}
# No. of combinations = {n \choose 1} = n
# \end{equation}
#
#
# >
# >https://www.calculatorsoup.com/calculators/discretemathematics/combinations.php?n=3&r=3&action=solve
# >

# %% [markdown]
# >## Quality problem
# >
# >***Rule: Consistency***
# >- (Q1) **`df2018`** and **`df2020`** contain missing values (NANs).

# %%
no_nulls = set(df2018.columns[df2018.isnull().mean()==0])#Provide a set of columns with 0 missing values.
no_nulls
# Out:
# {'Hobby', 'OpenSource', 'Respondent'}

# %% [markdown]
# In **`df2018`** there are only 3 variables ( i.e. columns) without missing values in at least one observation (i.e. row).
#
# Let us look at **`df2020`**

# %%
no_nulls = set(df2020.columns[df2020.isnull().mean()==0])#Provide a set of columns with 0 missing values.
no_nulls
# Out:
# {'Respondent'}

# %% [markdown]
# ## **Respondent** (Definition)
#
# >Randomized respondent ID number (not in order of survey response time).

# %% [markdown]
# In **`df2020`** there is only 1 variable ( i.e. column) without missing values in at least one observation.

# %% [markdown]
# >## Quality problem
# >
# >***Rule: Consistency***
# >- (Q2) **`df2020`** variables (i.e. columns) `Age1stCode` ,  `YearsCode` and `YearsCodePro`  contain dtype=object, rather than numerical values.

# %% [markdown]
# ## **Age1stCode** (Definition)
#
# >At what age did you write your first line of code or program? (e.g., webpage, Hello World, Scratch project)

# %%
df2020.Age1stCode.unique()
# Out:
# array(['13', '19', '15', '18', '16', '14', '12', '20', '42', '8', '25',
#        '22', '30', '17', '21', '10', '46', '9', '7', '11', '6', nan, '31',
#        '29', '5', 'Younger than 5 years', '28', '38', '23', '27', '41',
#        '24', '53', '26', '35', '32', '40', '33', '36', '54', '48', '56',
#        '45', '44', '34', 'Older than 85', '39', '51', '68', '50', '37',
#        '47', '43', '52', '85', '64', '55', '58', '49', '76', '72', '73',
#        '83', '63'], dtype=object)

# %% [markdown]
# ## **YearsCode** (Definition)
#
# >Including any education, how many years have you been coding in total?

# %%
df2020.YearsCode.unique()
# Out:
# array(['36', '7', '4', '15', '6', '17', '8', '10', '35', '5', '37', '19',
#        '9', '22', '30', '23', '20', '2', 'Less than 1 year', '3', '13',
#        '25', '16', '43', '11', '38', '33', nan, '24', '21', '12', '40',
#        '27', '50', '46', '14', '18', '28', '32', '44', '26', '42', '31',
#        '34', '29', '1', '39', '41', '45', 'More than 50 years', '47',
#        '49', '48'], dtype=object)

# %% [markdown]
# ## **YearsCodePro** (Definition)
#
# >NOT including education, how many years have you coded professionally (as a part of your work)?

# %%
df2020.YearsCodePro.unique()
# Out:
# array(['27', '4', nan, '8', '13', '2', '7', '20', '1', '23', '3', '12',
#        '17', '18', '10', '14', '29', '6', '28', '9', '15', '11', '16',
#        '25', 'Less than 1 year', '5', '21', '19', '35', '24', '32', '22',
#        '30', '38', '26', '40', '33', '31', 'More than 50 years', '34',
#        '36', '39', '37', '41', '45', '47', '42', '46', '50', '43', '44',
#        '48', '49'], dtype=object)

# %% [markdown]
# >## Tidiness problem
# >
# >***Rule: Each variable forms a column***
#
# >- (Q3) **`df2020`** column `DevType` contains a combination of all the developer types a respondent provided in the questionnaire.

# %% [markdown]
# ## **DevType** (Definition)
#
# >Which of the following describe you? Please select all that apply.

# %%
df2020.DevType.head(10)
# Out:
# 0    Developer, desktop or enterprise applications;...
# 1              Developer, full-stack;Developer, mobile
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5      Designer;Developer, front-end;Developer, mobile
# 6    Developer, back-end;Developer, front-end;Devel...
# 7    Developer, back-end;Developer, desktop or ente...
# 8                                Developer, full-stack
# 9    Database administrator;Developer, full-stack;D...
# Name: DevType, dtype: object

# %% [markdown]
# >## Tidiness problem
# >
# >***Rule: Each variable forms a column***
#
# >- (Q4) **`df2020`** column `MiscTechWorkedWith` contains a combination of all the technology types provided in the multiple choice question of the survey.

# %% [markdown]
# ## **MiscTechWorkedWith    &    MiscTechDesireNextYear** (Definitions)
#
# >Which other frameworks, libraries, and tools have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the framework and want to continue to do so, please check both boxes in that row.)

# %%
df2020.MiscTechWorkedWith.head(25)
# Out:
# 0                    .NET;.NET Core
# 1                      React Native
# 2                               NaN
# 3                               NaN
# 4                           Ansible
# 5                               NaN
# 6                               NaN
# 7                           Ansible
# 8                               NaN
# 9                            Pandas
# 10                          Node.js
# 11                             .NET
# 12                              NaN
# 13                          Node.js
# 14                              NaN
# 15                              NaN
# 16                     .NET;Node.js
# 17                              NaN
# 18           .NET;.NET Core;Node.js
# 19                          Node.js
# 20    Node.js;React Native;Unity 3D
# 21                              NaN
# 22                             .NET
# 23                              NaN
# 24                              NaN
# Name: MiscTechWorkedWith, dtype: object

# %% [markdown]
# >## Tidiness problem
# >
# >***Rule: Each variable forms a column***
#
# >- (Q5) **`df2018`** and **`df2020`** columns `LanguageWorkedWith` and `LanguageDesireNextYear` contain a combination of all the programming languages that a developer uses or would like to learn/use next year.

# %% [markdown]
# ## **LanguageWorkedWith  &  LanguageDesireNextYear** (Definitions)
# >Which programming, scripting, and markup languages have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the language and want to continue to do so, please check both boxes in that row.)

# %%
df2020.LanguageWorkedWith.head(5)
# Out:
# 0      C#;HTML/CSS;JavaScript
# 1            JavaScript;Swift
# 2    Objective-C;Python;Swift
# 3                         NaN
# 4           HTML/CSS;Ruby;SQL
# Name: LanguageWorkedWith, dtype: object

# %%
df2020.LanguageDesireNextYear.head(5)
# Out:
# 0      C#;HTML/CSS;JavaScript
# 1                Python;Swift
# 2    Objective-C;Python;Swift
# 3                         NaN
# 4             Java;Ruby;Scala
# Name: LanguageDesireNextYear, dtype: object

# %% [markdown]
# Now let us address the problems that we have identified.

# %% [markdown]
# ## Cleaning Data

# %% [markdown]
# ➔ Identify each step of the data cleaning process (defining, coding,
# and testing)
#
# ➔ Clean data using Python and pandas
#
# ➔ Test cleaning code visually and programmatically using Python

# %% [markdown]
# We start by copying the two annual dataframes. This way we can reverse all changes done during cleaning.

# %%
df2018_clean = df2018.copy()
df2020_clean = df2020.copy()

# %% [markdown]
# We should start the cleaning data process with data tidying (i.e. structuring datasets).

# %% [markdown]
# >## Quality problem
# >
# >***Rule: Consistency***
# >- (Q1) **`df2018`** and **`df2020`** contain missing values (NANs).

# %% [markdown]
# #### Define

# %% [markdown]
# - Remove missing values (i.e. NANs) from  **`df2018`** and **`df2020`** .

# %% [markdown]
# #### Code

# %%
# Create a dataframe without NAN values 
df2018_new = df2018_clean.dropna()
df2018_new.shape
# Out:
# (6, 129)

# %% [markdown]
# </font><font color='red'> ***There is a problem !***  <br></font><font color='black'> There are only 6 observations in **`df2018`** without missing values in at least one variable.
#
# In the 2018 developer survey, most respondants left some multiple choice questions unanswered.
#
# Let us have a look at **`df2020`**.

# %%
# Create a dataframe without NAN values 
df2020_new = df2020_clean.dropna()
df2020_new.shape
# Out:
# (4213, 61)

# %% [markdown]
# ***Not much better, there still is a problem***. There are only 4213 observations in **`df2020`** without missing values in at least one variable.

# %% [markdown]
# </font><font color='green'> ***Solution***  <br></font><font color='black'>In **`df2018`** and **`df2020`** we keep the NANs, because most respondants leave some questions unanswered and we do not want to miss any other information provided by respondants. However, later we will be analysing variables like `LanguageWorkedWith` and we will be deleting NANs in rows of those variables without affecting other variables (i.e. we don't delete entire rows for all variables).

# %% [markdown]
# #### Test

# %%
df2018_clean.LanguageWorkedWith.isnull().sum()
# Out:
# 20521

# %%
df2020_clean.LanguageWorkedWith.isnull().sum()
# Out:
# 7083

# %% [markdown]
# >## Quality problem
# >
# >***Rule: Consistency***
# >- (Q2) **`df2020`** variables (i.e. columns) `Age1stCode` ,  `YearsCode` and `YearsCodePro`  contain dtype=object, rather than numerical values.

# %% [markdown]
# #### Define

# %% [markdown]
# - Change string observations (i.e. pandas type 'object') of variable `Age1stCode` to numerical.
# - Change string observations (i.e. pandas type 'object') of variable `YearsCode` to numerical.
# - Change string observations (i.e. pandas type 'object') of variable `YearsCodePro` to numerical.

# %% [markdown]
# #### Code

# %%
# Replace the the strings with numerical values.
df2020_clean['Age1stCode']   = df2020_clean['Age1stCode'].replace(['Younger than 5 years','Older than 85'],['4','85'])
df2020_clean['YearsCode']    = df2020_clean['YearsCode'].replace(['Less than 1 year','More than 50 years'],['0.5','50'])
df2020_clean['YearsCodePro'] = df2020_clean['YearsCodePro'].replace(['Less than 1 year','More than 50 years'],['0.5','50'])

#df2020new = pd.to_numeric(df2020.YearsCode)
df2020_clean['Age1stCode']        = pd.to_numeric(df2020_clean['Age1stCode'])
df2020_clean['YearsCode']         = pd.to_numeric(df2020_clean['YearsCode'])
df2020_clean['YearsCodePro']      = pd.to_numeric(df2020_clean['YearsCodePro'])

# %% [markdown]
# #### Test

# %%
df2020_clean.describe() # The variables `Age1stCode` ,  `YearsCode` and `YearsCodePro` are of type float now.
# Out:
#          Respondent           Age    Age1stCode      CompTotal  ConvertedComp  \
# count  64461.000000  45446.000000  57900.000000   3.482600e+04   3.475600e+04
# mean   32554.079738     30.834111     15.410121  3.190464e+242   1.037561e+05
# std    18967.442360      9.585392      5.289951            inf   2.268853e+05
# min        1.000000      1.000000      4.000000   0.000000e+00   0.000000e+00
# 25%    16116.000000     24.000000     12.000000   2.000000e+04   2.464800e+04
# 50%    32231.000000     29.000000     15.000000   6.300000e+04   5.404900e+04
# 75%    49142.000000     35.000000     18.000000   1.250000e+05   9.500000e+04
# max    65639.000000    279.000000     85.000000  1.111111e+247   2.000000e+06
#
#         WorkWeekHrs     YearsCode  YearsCodePro
# count  41151.000000  57684.000000  46349.000000
# mean      40.782174     12.713135      8.514358
# std       17.816383      9.699281      7.875942
# min        1.000000      0.500000      0.500000
# ...

# %%
df2020_clean.hist();

# %% [markdown]
# >## Tidiness problem
# >
# >***Rule: Each variable forms a column***
#
# >- (Q3) **`df2020`** column `DevType` contains a combination of all the developer types provided in the multiple choice question of the survey.

# %% [markdown]
# #### Define

# %% [markdown]
# - Create a list of all the different developer types provided in the multiple choice questionnaire of the survey.
# - Create new columns in **`df2020`** of type boolean for each developer type listed in `DevType` .
# - Replace white spaces and special characters in the column names to facilitate access via dot notation
# - Create a new dataframe **`f2020_DevType`** that consists of the column `DevType` and the boolean variables mapped from **`df2020`**  `DevType`.
# - Delete NANs in **`f2020_DevType`**
# - Delete **`df2020`** column `DevType`, because all of the information is now provided in the new boolean variables (i.e. columns) for each of the developer types.

# %% [markdown]
# #### Code

# %% [markdown]
# Create a list of all the developer types provided in the multiple choice question of the survey.

# %%
DeveloperType = df2020_new.DevType.unique()

txt = []

for i in range(len(DeveloperType)):
    name = (DeveloperType[i].split(";"))
    txt.append(name)

DevType = set(list(chain.from_iterable(txt))) # The data type SET makes sure that 
                                              # every developer type only appears once

DevType
# Out:
# {'Academic researcher',
#  'Data or business analyst',
#  'Data scientist or machine learning specialist',
#  'Database administrator',
#  'Designer',
#  'DevOps specialist',
#  'Developer, QA or test',
#  'Developer, back-end',
#  'Developer, desktop or enterprise applications',
#  'Developer, embedded applications or devices',
#  'Developer, front-end',
#  'Developer, full-stack',
#  'Developer, game or graphics',
#  'Developer, mobile',
#  'Educator',
#  'Engineer, data',
#  'Engineer, site reliability',
#  'Engineering manager',
#  'Marketing or sales professional',
#  'Product manager',
#  'Scientist',
#  'Senior executive/VP',
#  'System administrator'}

# %% [markdown]
# We want to create new columns for each of the developer types provided in the survey. The variables are of type boolean.

# %%
def add_DevType(df):
    for name in DevType:
        df2020_clean[name] = False
        df2020_clean[name] = df2020_clean[df2020_clean['DevType'].str.contains(name, na=False)]
        df2020_clean[name] = (df2020_clean[name] > 0)
        print(name)

        
add_DevType(df2020_clean)
# Out:
# Developer, mobile
# Developer, embedded applications or devices
# Developer, back-end
# Marketing or sales professional
# Developer, full-stack
# Engineering manager
# Data scientist or machine learning specialist
# Academic researcher
# Developer, desktop or enterprise applications
# Developer, QA or test
# Scientist
# Designer
# Product manager
# Data or business analyst
# Senior executive/VP
# Engineer, site reliability
# Developer, game or graphics
# System administrator
# DevOps specialist
# Engineer, data
# Database administrator
# Educator
# Developer, front-end

# %% [markdown]
# Let us replace white spaces and special characters in the column names in order to facilitate access via dot notation.

# %%
df2020_clean.columns = df2020_clean.columns.str.replace(' ', '_')
df2020_clean.columns = df2020_clean.columns.str.replace(',', '')
df2020_clean.columns = df2020_clean.columns.str.replace('/', '_') 
df2020_clean.columns = df2020_clean.columns.str.replace('-', '')

# %% [markdown]
# Let us create a new dataframe **`df2020_DevType`** that consists of the column `DevType` and the 23 boolean variables mapped from `DevType`.

# %%
df2020_DevType = df2020_clean.filter(["DevType", "Academic_researcher" , "Scientist" ,"Data_or_business_analyst" ,
                                      "Data_scientist_or_machine_learning_specialist",
                                      "Developer_frontend", "Developer_backend", "Developer_fullstack" ,       
                                      "Developer_QA_or_test" , "Developer_desktop_or_enterprise_applications" ,  
                                      "Developer_game_or_graphics" ,    
                                      "Engineer_site_reliability" , "System_administrator" ,  
                                      "DevOps_specialist" , "Developer_embedded_applications_or_devices"  , 
                                      "Developer_mobile" , "Database_administrator" ,
                                      "Engineer_data" , "Engineering_manager" ,        
                                      "Educator" , "Marketing_or_sales_professional" ,  
                                      "Designer" , "Product_manager" ,  
                                      "Senior_executive_VP" ,  ], axis=1)

# %% [markdown]
# Now we drop all rows with NANs in column **`f2020_DevType`**  `DevType` and keep the changes.

# %%
df2020_DevType = df2020_DevType.dropna(subset=['DevType'], axis=0) 
df2020_DevType.shape
# Out:
# (49370, 24)

# %% [markdown]
# What is the share of recipients in the survey who provided an answer to the `DevType` question?

# %%
DevType_nonNANs = df2020_clean.DevType.count() / df2020_clean.DevType.shape[0]  
DevType_nonNANs
# Out:
# 0.765889452537193

# %% [markdown]
# We delete the **`df2020`** column `DevType`, because all of the information is now provided in the 23 new boolean variables (i.e. columns) for each of the developer types.

# %%
df2020_clean = df2020_clean.drop(['DevType'], axis=1)

# %% [markdown]
# #### Test

# %%
df2020_DevType.tail(10)
# Out:
#                                                  DevType  Academic_researcher  \
# 64429                                  Developer, mobile                False
# 64432  Data scientist or machine learning specialist;...                False
# 64437                           Data or business analyst                False
# 64446  Academic researcher;Data or business analyst;D...                 True
# 64447                                Developer, back-end                False
# 64448  Developer, back-end;Developer, desktop or ente...                False
# 64449                                  Developer, mobile                False
# 64451      Data scientist or machine learning specialist                False
# 64453  Data or business analyst;Developer, mobile;Sen...                False
# 64456                                Senior executive/VP                False
#
#        Scientist  Data_or_business_analyst  \
# 64429      False                     False
# ...

# %%
df2020_clean.dtypes.tail(23)
# Out:
# Developer_mobile                                 bool
# Developer_embedded_applications_or_devices       bool
# Developer_backend                                bool
# Marketing_or_sales_professional                  bool
# Developer_fullstack                              bool
# Engineering_manager                              bool
# Data_scientist_or_machine_learning_specialist    bool
# Academic_researcher                              bool
# Developer_desktop_or_enterprise_applications     bool
# Developer_QA_or_test                             bool
# Scientist                                        bool
# Designer                                         bool
# Product_manager                                  bool
# Data_or_business_analyst                         bool
# Senior_executive_VP                              bool
# Engineer_site_reliability                        bool
# Developer_game_or_graphics                       bool
# ...

# %% [markdown]
# We should be able to read the share of each developer type now.

# %%
DevType_share = df2020_DevType.mean().tail(23).sort_values() 
DevType_share
# Out:
# Marketing_or_sales_professional                  0.013004
# Senior_executive_VP                              0.026737
# Engineer_site_reliability                        0.039295
# Scientist                                        0.042252
# Product_manager                                  0.050577
# Engineering_manager                              0.055175
# Developer_game_or_graphics                       0.056492
# Educator                                         0.059307
# Academic_researcher                              0.071947
# Engineer_data                                    0.075714
# Developer_QA_or_test                             0.079947
# Data_scientist_or_machine_learning_specialist    0.080778
# Data_or_business_analyst                         0.081507
# Developer_embedded_applications_or_devices       0.096212
# System_administrator                             0.106178
# Designer                                         0.107778
# ...

# %% [markdown]
# How many developer roles do the respondants of the 2020 survey perform on average?

# %%
DevType_share.sum()
# Out:
# 3.181972858010938

# %% [markdown]
# We verify our results by comparing them with Stackoverflow's analysis of ***Developer Roles*** for all Respondants of their 2020 survey.
#
# https://insights.stackoverflow.com/survey/2020#developer-roles
#
# >`About 55% of respondents identify as full-stack developers, and about 20% consider themselves mobile developers. The median number of developer type identifications per respondent this year is three, and the most common combinations include back-end, front-end, and full-stack developer. Pairs that are highly correlated include database administrator and system administrator, DevOps specialist and site reliability engineer, academic researcher and scientist, and designer and front-end developer.`
# >
# >All Respondents 49,370 responses; select all`

# %%
df2020_DevType.shape[0]
# Out:
# 49370

# %% [markdown]
# We can verify the percentage share of `[Developer_fullstack]` and `[Developer_mobile]` . However, we have not looked at correlations between ***Developer Roles*** .
#
# There are n = 23 binary option in the **`df2020`** `DevType` variable. Therefore, there are
#
# \begin{equation}
# 2^n - 1
# \end{equation}
#
# or **8.4 million** possible combinations. Nevertheless, we have already calculated that developers on average provide 'only' 3.2 developer roles (see above). We can calculate the number of possible combinations of choosing x = 4 options (rounding up) out of n possible answers (i.e. n choose x):
#
# \begin{equation}
# {n \choose x}
# \end{equation}
#
# There are n = 23 binary option and developers pick x = 4 , than there are ***8855*** **possible combinations**. In fact, we **observe** ***8269*** **unique entries** in **`df2020`** `DevType` .
#
# https://www.calculatorsoup.com/calculators/discretemathematics/combinations.php?n=3&r=3&action=solve
#
#
# We would like to know if all the possible combinations are equally likely, or do we observe higher correlations between pairs?

# %%
ig, ax = plt.subplots(figsize=(15,15))         # Sample figsize in inches
#sns.heatmap(df1.iloc[:, 1:6:], annot=True, linewidths=.5, ax=ax)

sns.heatmap(df2020_DevType.corr(), annot=True, fmt=".1f", linewidths=.5);

# %% [markdown]
# We can confirm:
#
# >there is a **correlation of 0.3** between `[back-end]`, `[front-end]`, and `[full-stack developer]`.
# >
# >Pairs that are highly correlated include
# >
# >`[database administrator]` and `[system administrator]` (**correlation 0.4**)
# >
# >`[DevOps specialist]` and `[site reliability engineer]` (**correlation 0.3**) ,
# >
# >`[academic researcher]` and `[scientist]` (**correlation 0.4**), and
# >
# >`[designer]` and `[front-end developer]` (**correaltion 0.2**).

# %% [markdown]
# We have verified our mapping results for **`df2020`** `DevType`. We have created new columns for each of the developer types provided in the questionnaire.

# %% [markdown]
# >## Tidiness problem
# >
# >***Rule: Each variable forms a column***
#
# >- (Q4) **`df2020`** column `MiscTechWorkedWith` contains a combination of all the technology types provided in the multiple choice question of the survey.

# %% [markdown]
# #### Define

# %% [markdown]
# - Create a list of all the different technologies provided in the multiple choice questionnaire of the survey.
# - Create new columns in **`df2020`** of type boolean for each developer type listed in `MiscTechWorkedWith` .
# - Replace white spaces and special characters in the column names to facilitate access via dot notation
# - Create a new dataframe **`f2020_MiscTechWorkedWith`** that consists of the column `MiscTechWorkedWith`
#   and the boolean variables mapped from **`df2020`**  `MiscTechWorkedWith`.
# - Delete NANs in **`f2020_MiscTechWorkedWith`**
# - Delete **`df2020`** column `MiscTechWorkedWith`

# %%
MiscTechWorkedWith = df2020_new.MiscTechWorkedWith.unique()

txt = []

for i in range(len(MiscTechWorkedWith)):
    name = (MiscTechWorkedWith[i].split(";"))
    txt.append(name)

MiscTechWorkedWith = set(list(chain.from_iterable(txt))) # The data type SET makes sure that 
                                                         # every technology only appears once
len(MiscTechWorkedWith)
# Out:
# 19

# %% [markdown]
# There are 19 different technologies to choose from in this question of the survey.

# %%
# We add a semicolon at the end of every observation of the variable MiscTechWorkedWith to help us identifying 
# the technologies correctly.

df2020_clean.MiscTechWorkedWith = df2020_clean.MiscTechWorkedWith + ";"

# %% [markdown]
# We want to create new columns for each of the technologies provided in the survey. The variables are of type boolean.

# %%
def add_MiscTechWorkedWith(df):
    for name in MiscTechWorkedWith:
        df2020_clean[name] = False
        df2020_clean[name] = df2020_clean[df2020_clean['MiscTechWorkedWith'].str.contains(name + ';', na=False)]
        df2020_clean[name] = (df2020_clean[name] > 0)
        print(name)

        
add_MiscTechWorkedWith(df2020_clean)
# Out:
# React Native
# Cordova
# Torch/PyTorch
# Unreal Engine
# Pandas
# Teraform
# Node.js
# Ansible
# Unity 3D
# Chef
# Hadoop
# Apache Spark
# Puppet
# Xamarin
# .NET Core
# Flutter
# TensorFlow
# Keras
# .NET

# %% [markdown]
# Let us create a new dataframe **`df2020_MiscTechWorkedWith`** that consists of the column `MiscTechWorkedWith` and the 19 boolean variables mapped from `MiscTechWorkedWith`.

# %%
df2020_MiscTechWorkedWith = df2020_clean.filter(["MiscTechWorkedWith", ".NET" , "Puppet" ,"Cordova" ,
                                      "Unreal Engine", "Node.js", "Pandas", "TensorFlow" ,       
                                      "React Native" , "Torch/PyTorch" ,  "Chef" , "Hadoop" , "Flutter" ,  
                                      "Apache Spark" , "Teraform", "Unity 3D" , "Keras" ,
                                      ".NET Core" , "Xamarin" , "Ansible" ], axis=1)

# %% [markdown]
# Now we drop all rows with NANs in column **`f2020_MiscTechWorkedWith`**  `MiscTechWorkedWith` and keep the changes.

# %%
df2020_MiscTechWorkedWith = df2020_MiscTechWorkedWith.dropna(subset=['MiscTechWorkedWith'], axis=0) 
df2020_MiscTechWorkedWith.shape
# Out:
# (40314, 20)

# %%
df2020_MiscTechWorkedWith.head()
# Out:
#   MiscTechWorkedWith   .NET  Puppet  Cordova  Unreal Engine  Node.js  Pandas  \
# 0    .NET;.NET Core;   True   False    False          False    False   False
# 1      React Native;  False   False    False          False    False   False
# 4           Ansible;  False   False    False          False    False   False
# 7           Ansible;  False   False    False          False    False   False
# 9            Pandas;  False   False    False          False    False    True
#
#    TensorFlow  React Native  Torch/PyTorch   Chef  Hadoop  Flutter  \
# 0       False         False          False  False   False    False
# 1       False          True          False  False   False    False
# 4       False         False          False  False   False    False
# 7       False         False          False  False   False    False
# 9       False         False          False  False   False    False
#
#    Apache Spark  Teraform  Unity 3D  Keras  .NET Core  Xamarin  Ansible
# ...

# %% [markdown]
# What is the share of recipients in the 2020 survey who provided an answer to the `MiscTechWorkedWith` question?

# %%
MiscTechWorkedWith_nonNANs = df2020_clean.MiscTechWorkedWith.count() / df2020_clean.MiscTechWorkedWith.shape[0]  
MiscTechWorkedWith_nonNANs
# Out:
# 0.6254014055010007

# %% [markdown]
# We delete the **`df2020`** column `MiscTechWorkedWith`, because all of the information is now provided in the 19 new boolean variables (i.e. columns) for each of the technology types.

# %%
df2020_clean = df2020_clean.drop(['MiscTechWorkedWith'], axis=1)

# %% [markdown]
# #### Test

# %%
df2020_clean.dtypes.tail(19)
# Out:
# React Native     bool
# Cordova          bool
# Torch/PyTorch    bool
# Unreal Engine    bool
# Pandas           bool
# Teraform         bool
# Node.js          bool
# Ansible          bool
# Unity 3D         bool
# Chef             bool
# Hadoop           bool
# Apache Spark     bool
# Puppet           bool
# Xamarin          bool
# .NET Core        bool
# Flutter          bool
# TensorFlow       bool
# Keras            bool
# .NET             bool
# dtype: object

# %% [markdown]
# We should be able to read the share of each technology.

# %%
MiscTechWorkedWith_share = df2020_MiscTechWorkedWith.mean().tail(19).sort_values() 
MiscTechWorkedWith_share
# Out:
# Chef             0.018182
# Puppet           0.023441
# Unreal Engine    0.032644
# Hadoop           0.044600
# Torch/PyTorch    0.046435
# Apache Spark     0.051818
# Xamarin          0.058466
# Cordova          0.060004
# Keras            0.062112
# Teraform         0.062460
# Flutter          0.071861
# Ansible          0.073300
# Unity 3D         0.109466
# React Native     0.114749
# TensorFlow       0.115394
# Pandas           0.155107
# .NET Core        0.266781
# .NET             0.350846
# Node.js          0.514486
# dtype: float64

# %% [markdown]
# We verify our results by comparing them with Stackoverflow's analysis of ***Other Frameworks, Libraries, and Tools*** for all Respondants in the 2020 survey.
#
# > https://insights.stackoverflow.com/survey/2020#most-popular-technologies
# >
# >`Similar to last year, we asked about many of the other miscellaneous technologies that developers are using. For the second year in a row, Node.js takes the top spot, as it is used by half of the respondents. We also see growth across the board in the popularity of data analysis and machine learning technologies such as Pandas, TensorFlow, and Torch/PyTorch.`
# >
# >40,314 responses; select all that apply"

# %%
df2020_MiscTechWorkedWith.count().head(1)
# Out:
# MiscTechWorkedWith    40314
# dtype: int64

# %% [markdown]
# >We can verify that `[Node.js]` is the most popular technology used by 51.4 percent of respondants. The data analysis and machine learning technologies `[Pandas]`, `[TensorFlow]` , and `[Torch/PyTorch]` are used by 15.5 percent ,  11.5 percent and 4.6 percent , respectively.
# >
#
#
# We have verified our mapping results for **`df2020`** `MiscTechWorkedWith`. We have created new columns for each of the technologies provided as an option in the questionnaire.

# %% [markdown]
# >## Tidiness problem
# >
# >***Rule: Each variable forms a column***
#
# >- (Q5) **`df2018`** and **`df2020`** columns `LanguageWorkedWith` and `LanguageDesireNextYear` contain a combination of all the programming languages that a developer uses or would like to learn/use next year.

# %% [markdown]
# #### Define

# %% [markdown]
# - Create a list of all the different languages provided in the multiple choice questionnaires of the two surveys.
# - Create new columns in **`df2018`** and **`df2020`** of type boolean for each language listed in `LanguageWorkedWith` .

# %% [markdown]
# #### Code

# %%
language2018 = df2018_clean.LanguageWorkedWith.dropna().unique()

txt = []

for i in range(len(language2018)):
    name = (language2018[i].split(";"))
    txt.append(name)

programming_language2018 = set(list(chain.from_iterable(txt)))
programming_language2018
# Out:
# {'Assembly',
#  'Bash/Shell',
#  'C',
#  'C#',
#  'C++',
#  'CSS',
#  'Clojure',
#  'Cobol',
#  'CoffeeScript',
#  'Delphi/Object Pascal',
#  'Erlang',
#  'F#',
#  'Go',
#  'Groovy',
#  'HTML',
#  'Hack',
#  'Haskell',
#  'Java',
#  'JavaScript',
#  'Julia',
#  'Kotlin',
#  'Lua',
#  'Matlab',
#  'Objective-C',
#  'Ocaml',
#  'PHP',
#  'Perl',
#  'Python',
#  'R',
#  'Ruby',
#  'Rust',
#  'SQL',
#  'Scala',
#  'Swift',
#  'TypeScript',
#  'VB.NET',
#  'VBA',
#  'Visual Basic 6'}

# %%
len(programming_language2018)
# Out:
# 38

# %% [markdown]
# In **`df2018`** there are 38 programming languages.
#
# Let us see how many programming languages were used in **`df2020`** .

# %%
language2020 = df2020_clean.LanguageWorkedWith.dropna().unique()


txt = []

for i in range(len(language2020)):
    name = (language2020[i].split(";"))
    txt.append(name)

programming_language2020 = set(list(chain.from_iterable(txt)))
programming_language2020
# Out:
# {'Assembly',
#  'Bash/Shell/PowerShell',
#  'C',
#  'C#',
#  'C++',
#  'Dart',
#  'Go',
#  'HTML/CSS',
#  'Haskell',
#  'Java',
#  'JavaScript',
#  'Julia',
#  'Kotlin',
#  'Objective-C',
#  'PHP',
#  'Perl',
#  'Python',
#  'R',
#  'Ruby',
#  'Rust',
#  'SQL',
#  'Scala',
#  'Swift',
#  'TypeScript',
#  'VBA'}

# %%
len(programming_language2020)
# Out:
# 25

# %% [markdown]
# In **`df2020`** there are only 25 programming languages. In contrast to the 2018 survey, the two programming languages ``[HTML]`` and ``[CSS]`` have been combined to ``[HTML/CSS]`` and ``[Bash/Shell]`` has been expanded to ``[Bash/Shell/PowerShell]``.

# %%
programming_language_difference = programming_language2020.difference(programming_language2018) 
programming_language_difference
# Out:
# {'Bash/Shell/PowerShell', 'Dart', 'HTML/CSS'}

# %% [markdown]
# We will be using these lists of programming languages.

# %%
programming_language2018 = ['Assembly;', 'Bash/Shell;', 'C;', 'C#;', 'C++;', 'CSS;', 'Clojure;', 'Cobol;', 'CoffeeScript;',
                            'Delphi/Object Pascal;', 'Erlang;', 'F#;', 'Go;', 'Groovy;', 'HTML;', 'Hack;', 'Haskell;', 
                            'Java;', 'JavaScript;', 'Julia;', 'Kotlin;', 'Lua;', 'Matlab;', 'Objective-C;', 'Ocaml;', 
                            'PHP;', 'Perl;', 'Python;', 'R;', 'Ruby;', 'Rust;', 'SQL;', 'Scala;', 'Swift;', 'TypeScript;',
                            'VB.NET;', 'VBA;', 'Visual Basic 6;']
    
    
    
programming_language2020 = ["Assembly;", "Bash/Shell/PowerShell;", "C;", "C#;", "C++;",
                 "Dart;", "Go;","HTML/CSS;", "Haskell;", "Java;", 
                 "JavaScript;", "Julia;", "Kotlin;", "Objective-C;","PHP;",
                 "Perl;","Python;", "R;", "Ruby;", "Rust;",
                 "SQL;","Scala;", "Swift;", "TypeScript;", "VBA;"]
    
    
# We add a semicolon at the end of every observation of the variables LanguageWorkedWith and LanguageDesireNextYear
# to help us identifying the programming languages correctly.
    
df2018_clean.LanguageDesireNextYear = df2018_clean.LanguageDesireNextYear + ";"
df2018_clean.LanguageWorkedWith     = df2018_clean.LanguageWorkedWith + ";"
df2020_clean.LanguageDesireNextYear = df2020_clean.LanguageDesireNextYear + ";"
df2020_clean.LanguageWorkedWith     = df2020_clean.LanguageWorkedWith + ";"

# %% [markdown]
# We want to create new columns for each of the 38 programming languages provided in **`df2018`**  `LanguageWorkedWith` . The variables are of type boolean.

# %%
# time efficient methode to map the column into boolean variables
for name in programming_language2018:
    df2018_clean[name] = False  # assign a new column with boolean value False by default
    df2018_clean[name] = df2018_clean[df2018_clean['LanguageWorkedWith'].str.contains (name, na=False, regex = False)] 
    df2018_clean[name] = (df2018_clean[name] > 0)
    print(name)

# We need to correct the doubble counting of "C;" and "Objective-C;" 

df2018_clean['Language'] = df2018_clean['LanguageWorkedWith'].str.replace(r'Objective-C;', '')
df2018_clean['C;']       =  False
df2018_clean['C;']       =  df2018_clean[df2018_clean['Language'].str.contains ('C;', na=False, regex = False)] 
df2018_clean['C;']       = (df2018_clean['C;'] > 0)
df2018_clean             = df2018_clean.drop(['Language'], axis=1)
# Out:
# Assembly;
# Bash/Shell;
# C;
# C#;
# C++;
# CSS;
# Clojure;
# Cobol;
# CoffeeScript;
# Delphi/Object Pascal;
# Erlang;
# F#;
# Go;
# Groovy;
# HTML;
# Hack;
# Haskell;
# Java;
# JavaScript;
# Julia;
# Kotlin;
# Lua;
# Matlab;
# Objective-C;
# Ocaml;
# PHP;
# Perl;
# Python;
# R;
# Ruby;
# Rust;
# SQL;
# Scala;
# Swift;
# TypeScript;
# VB.NET;
# VBA;
# Visual Basic 6;

# %% [markdown]
# We want to create new columns for each of the 25 programming languages provided in **`df2020`**  `LanguageWorkedWith` . The variables are of type boolean.

# %%
for name in programming_language2020:
    df2020_clean[name] = False
    df2020_clean[name] = df2020_clean[df2020_clean['LanguageWorkedWith'].str.contains (name, na=False, regex = False)] 
    df2020_clean[name] = (df2020_clean[name] > 0)
    print(name)

        
# df2020_clean['C;'] =   (df2020_clean['C;']) & (~df2020_clean['Objective-C;']) 

df2020_clean['Language'] = df2020_clean['LanguageWorkedWith'].str.replace(r'Objective-C;', '')
df2020_clean['C;']       =  False
df2020_clean['C;']       =  df2020_clean[df2020_clean['Language'].str.contains ('C;', na=False, regex = False)] 
df2020_clean['C;']       = (df2020_clean['C;'] > 0)
df2020_clean             = df2020_clean.drop(['Language'], axis=1)
# Out:
# Assembly;
# Bash/Shell/PowerShell;
# C;
# C#;
# C++;
# Dart;
# Go;
# HTML/CSS;
# Haskell;
# Java;
# JavaScript;
# Julia;
# Kotlin;
# Objective-C;
# PHP;
# Perl;
# Python;
# R;
# Ruby;
# Rust;
# SQL;
# Scala;
# Swift;
# TypeScript;
# VBA;

# %% [markdown]
# We will be using the dataframe **`df2018_LanguageWorkedWith`** that consists of the column `LanguageWorkedWith` and the 38 boolean variables mapped from **`df2018`**  `LanguageWorkedWith`.

# %%
df2018_LanguageWorkedWith = df2018_clean.filter(['LanguageWorkedWith', 'Assembly;', 'Bash/Shell;', 
                                                 'C;', 'C#;', 'C++;', 'CSS;', 'Clojure;', 'Cobol;', 'CoffeeScript;',
                                                 'Delphi/Object Pascal;', 'Erlang;', 'F#;','Go;', 'Groovy;', 
                                                 'HTML;', 'Hack;', 'Haskell;', 'Java;', 'JavaScript;', 'Julia;', 
                                                 'Kotlin;', 'Lua;', 'Matlab;', 'Objective-C;', 'Ocaml;', 
                                                 'PHP;', 'Perl;', 'Python;', 'R;', 'Ruby;', 'Rust;', 
                                                 'SQL;', 'Scala;', 'Swift;', 'TypeScript;',
                                                 'VB.NET;', 'VBA;', 'Visual Basic 6;'], axis=1)

# %% [markdown]
# Now we drop all rows with NANs in column **`f2018_LanguageWorkedWith`**  `LanguageWorkedWith` and keep the changes.

# %%
df2018_LanguageWorkedWith = df2018_LanguageWorkedWith.dropna(subset=['LanguageWorkedWith'], axis=0) 
df2018_LanguageWorkedWith.shape
# Out:
# (78334, 39)

# %% [markdown]
# What is the share of recipients in **`df2018`** who provided an answer to the `LanguageWorkedWith` question?

# %%
LanguageWorkedWith_nonNANs2018 = df2018_clean.LanguageWorkedWith.count() / df2018_clean.LanguageWorkedWith.shape[0]  
LanguageWorkedWith_nonNANs2018
# Out:
# 0.7924131303424207

# %% [markdown]
# We will be using the dataframe **`df2020_LanguageWorkedWith`** that consists of the column `LanguageWorkedWith` and the 25 boolean variables mapped from **`df2020`**  `LanguageWorkedWith`.

# %%
df2020_LanguageWorkedWith = df2020_clean.filter(['LanguageWorkedWith', "Assembly;", "Bash/Shell/PowerShell;", 
                                                 "C;", "C#;", "C++;", "Dart;", "Go;", "HTML/CSS;", "Haskell;", 
                                                 "Java;", "JavaScript;", "Julia;", "Kotlin;", "Objective-C;",
                                                 "PHP;", "Perl;","Python;", 
                                                 "R;", "Ruby;", "Rust;",
                                                 "SQL;","Scala;", "Swift;", 
                                                 "TypeScript;", "VBA;"], axis=1)

# %% [markdown]
# Now we drop all rows with NANs in column **`df2020_LanguageWorkedWith`**  `LanguageWorkedWith` and keep the changes.

# %%
df2020_LanguageWorkedWith = df2020_LanguageWorkedWith.dropna(subset=['LanguageWorkedWith'], axis=0) 
df2020_LanguageWorkedWith.shape
# Out:
# (57378, 26)

# %% [markdown]
# What is the share of recipients in **`df2020`** who provided an answer to the `LanguageWorkedWith` question?

# %%
LanguageWorkedWith_nonNANs = df2020_clean.LanguageWorkedWith.count() / df2020_clean.LanguageWorkedWith.shape[0]  
LanguageWorkedWith_nonNANs
# Out:
# 0.8901196072043561

# %% [markdown]
# #### Test

# %%
df2018_clean.dtypes.tail(38)
# Out:
# Assembly;                bool
# Bash/Shell;              bool
# C;                       bool
# C#;                      bool
# C++;                     bool
# CSS;                     bool
# Clojure;                 bool
# Cobol;                   bool
# CoffeeScript;            bool
# Delphi/Object Pascal;    bool
# Erlang;                  bool
# F#;                      bool
# Go;                      bool
# Groovy;                  bool
# HTML;                    bool
# Hack;                    bool
# Haskell;                 bool
# Java;                    bool
# JavaScript;              bool
# Julia;                   bool
# Kotlin;                  bool
# Lua;                     bool
# Matlab;                  bool
# Objective-C;             bool
# Ocaml;                   bool
# PHP;                     bool
# Perl;                    bool
# Python;                  bool
# R;                       bool
# Ruby;                    bool
# Rust;                    bool
# ...

# %%
df2020_clean.dtypes.tail(25)
# Out:
# Assembly;                 bool
# Bash/Shell/PowerShell;    bool
# C;                        bool
# C#;                       bool
# C++;                      bool
# Dart;                     bool
# Go;                       bool
# HTML/CSS;                 bool
# Haskell;                  bool
# Java;                     bool
# JavaScript;               bool
# Julia;                    bool
# Kotlin;                   bool
# Objective-C;              bool
# PHP;                      bool
# Perl;                     bool
# Python;                   bool
# R;                        bool
# Ruby;                     bool
# Rust;                     bool
# SQL;                      bool
# Scala;                    bool
# Swift;                    bool
# TypeScript;               bool
# VBA;                      bool
# dtype: object

# %% [markdown]
# We should be able to read the share of each language worked with in 2018.

# %%
df2018_LanguageWorkedWith_share = df2018_LanguageWorkedWith.mean().tail(38).sort_values() 
df2018_LanguageWorkedWith_share
# Out:
# Hack;                    0.003243
# Julia;                   0.005489
# Ocaml;                   0.006000
# Cobol;                   0.007532
# Erlang;                  0.011311
# Clojure;                 0.013174
# F#;                      0.014234
# Rust;                    0.023706
# Haskell;                 0.025034
# Delphi/Object Pascal;    0.025851
# CoffeeScript;            0.033230
# Lua;                     0.034889
# Visual Basic 6;          0.039408
# Perl;                    0.041872
# Groovy;                  0.043059
# Scala;                   0.043659
# Kotlin;                  0.044783
# VBA;                     0.048638
# Matlab;                  0.058263
# R;                       0.061442
# VB.NET;                  0.067072
# Objective-C;             0.070340
# Go;                      0.070621
# Assembly;                0.073531
# Swift;                   0.080553
# Ruby;                    0.100991
# TypeScript;              0.173947
# ...

# %% [markdown]
# We verify our results by comparing them with Stackoverflow's 2018 analysis of ***Programming, Scripting, and Markup Languages*** for all Respondants.
#
# >https://insights.stackoverflow.com/survey/2018#technology-_-programming-scripting-and-markup-languages
# >
# >`For the sixth year in a row, JavaScript is the most commonly used programming language. Python has risen in the ranks, surpassing C# this year, much like it surpassed PHP last year. Python has a solid claim to being the fastest-growing major programming languag.`
# >
# >`We see close alignment in the technology choices of professional developers and the developer population overall.`
#
#
#
# 78,334 responses; select all that apply

# %%
df2018_LanguageWorkedWith.shape[0]
# Out:
# 78334

# %% [markdown]
# >We can confirm that in the 2018 survey, `[JavaScript]` is the most popular language, used by 70 percent of respondants.
# >We can confirm that `[Python]` (38.8 percent) has surpassed both `[C#]` (34.4 percent) and `[PHP]` (30.7 percent) .
#
# We have verified our results for the mapping of **`df2018`** `LanguageWorkedWith`.

# %% [markdown]
# We should be able to read the share of each language worked with in 2020.

# %%
df2020_LanguageWorkedWith_share = df2020_LanguageWorkedWith.mean().tail(25).sort_values() 
df2020_LanguageWorkedWith_share
# Out:
# Julia;                    0.009045
# Haskell;                  0.021297
# Perl;                     0.031301
# Scala;                    0.035763
# Dart;                     0.039736
# Objective-C;              0.040782
# Rust;                     0.051047
# R;                        0.057304
# Swift;                    0.059204
# VBA;                      0.060982
# Assembly;                 0.061923
# Ruby;                     0.070515
# Kotlin;                   0.077870
# Go;                       0.087804
# C;                        0.217627
# C++;                      0.238889
# TypeScript;               0.254070
# PHP;                      0.261546
# C#;                       0.314424
# Bash/Shell/PowerShell;    0.330789
# Java;                     0.402140
# Python;                   0.440709
# SQL;                      0.547475
# HTML/CSS;                 0.630573
# JavaScript;               0.676601
# dtype: float64

# %% [markdown]
# We verify our results by comparing them with Stackoverflow's analysis of ***Programming, Scripting, and Markup Languages*** for all Respondants.
#
# > https://insights.stackoverflow.com/survey/2020#most-popular-technologies
# >
# >`Unsurprisingly, for the eighth year in a row, JavaScript has maintained it's stronghold as the most commonly used programming language. Going further down the list, we also see moderate gains for TypeScript, edging out C in terms of popularity. Additionally, Ruby, once in the top 10 of this list as recently as 2017, has declined, being surpassed by newer, trendier technologies such as Go and Kotlin.`
# >
# 57,378 responses; select all that apply"

# %%
df2020_clean.LanguageWorkedWith.count()
# Out:
# 57378

# %% [markdown]
# >We can confirm that in the 2020 survey `[JavaScript]` is the most popular programming language used by 67.7 percent of respondants.
#
# We have verified our results for the mapping of **`df2020`** `LanguageWorkedWith`.

# %% [markdown]
# <a id='structure'></a>
# # What is the structure of the 2020 dataset? #
#
# The Developer Survey 2020 contains 61 questions (i.e. columns) and we have added boolean variables for developer type `DevType`, language currently worked with `LanguageWorkedWith` and miscellaneous technology currently worked with `MiscTechWorkedWith`.
#
#
# </font><font color='blue'> **Identifiers and Keys**:<br></font><font color='black'>
#
# >**Respondent**: Randomized respondent ID number (not in order of survey response time)
#
#  </font><font color='brown'> **64461 unique entries**:<br></font><font color='black'>
#
#
#
# </font><font color='blue'> **Numeric Variables**: (Integer) or (Float) <br></font><font color='black'>
#
#
# > **Age**: What is your age (in years)?
# >
# >
# > **Age1stCode**:   At what age did you write your first line of code or program? (e.g., webpage, Hello World, Scratch project)
# >
# > **CompTotal**:    What is your current total compensation (salary, bonuses, and perks, before taxes and deductions), in `CurrencySymbol`? Please enter a whole number in the box below, without any punctuation. If you are paid hourly, please estimate an equivalent weekly, monthly, or yearly salary. If you prefer not to answer, please leave the box empty.
# >
# >**ConvertedComp**
# >Salary converted to annual USD salaries using the exchange rate on 2020-02-19, assuming 12 working months and 50 working weeks.
# >
# > **WorkWeekHrs**: On average, how many hours per week do you work? Please enter a whole number in the box.
# >
# >
# > **YearsCode** :  Including any education, how many years have you been coding in total?
# >
# >
# > **YearsCodePro**: NOT including education, how many years have you coded professionally (as a part of your work)?
#
#
# </font><font color='blue'> **Categorical variables with only one option to choose from** ***(choose one)***<br></font><font color='black'>
#
#
#
# >**CompFreq**  Is that compensation weekly, monthly, or yearly?
# >
# >**Country** Where do you live?
# >>***180 countries and dependent territories*** to choose from
# >
# >**CurrencyDesc**  Which currency do you use day-to-day? If your answer is complicated, please pick the one you're most comfortable estimating in.
# >
# >**CurrencySymbol** Which currency do you use day-to-day? If your answer is complicated, please pick the one you're most comfortable estimating in.
# >
# >**EdLevel**  Which of the following best describes the highest level of formal education that you have completed?
# >>***Associate degree (A.A., A.S., etc.)***  ,
# >>*Bachelor’s degree (B.A., B.S., B.Eng., etc.*  ,
# >>***I never completed any formal education***  ,
# >>*Master’s degree (M.A., M.S., M.Eng., MBA, etc.)*
# >>***Other doctoral degree (Ph.D., Ed.D., etc.***
# >>*Primary/elementary school*
# >>***Professional degree (JD, MD, etc.)***
# >>*Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)*
# >>***Some college/university study without earning a degree***
# >
# >**Employment**  Which of the following best describes your current employment status?
# >>***Employed full-time***
# >>*Employed part-time*
# >>***Independent contractor, freelancer, or self-employed***
# >>*Not employed, and not looking for work*
# >>***Not employed, but looking for work***
# >>*Retired*
# >>***Student***
# >
# >**Hobbyist** Do you code as a hobby?
# >>**Yes**
# >>*No*
# >
# >**JobSat**  How satisfied are you with your current job? (If you work multiple jobs, answer for the one you spend the most hours on.)
# >>***Neither satisfied nor dissatisfied***
# >>*Slightly dissatisfied*
# >>***Slightly satisfied***
# >>*Very dissatisfied*
# >>***Very satisfied***
# >
# >**JobSeek**  Which of the following best describes your current job-seeking status?
# >
# >>***I am actively looking for a job***
# >>*I am not interested in new job opportunities*
# >>***I’m not actively looking, but I am open to new opportunities***
# >>*I’m not actively looking, but I am open to new opportunities*
# >
# >**NEWDevOps**: Does your company have a dedicated DevOps person?
# >
# >>**No**
# >>*Not sure*
# >>**Yes**
# >
# >**NEWDevOpsImpt**: How important is the practice of DevOps to scaling software development?
# >
# >>***Extremely important***
# >>*Neutral*
# >>***Not at all important***
# >>*Not very important*
# >>***Somewhat important***
# >
# >**NEWEdImpt**: How important is a formal education, such as a university degree in computer science, to your career?
# >
# >>***Critically important***
# >>*Fairly important*
# >>***Not at all important/not necessary***
# >>*Somewhat important*
# >>***Very important***
# >
# >**NEWLearn**: How frequently do you learn a new language or framework?
# >
# >>***Every few months***
# >>*Once a decade*
# >>***Once a year***
# >>*Once every few years*
# >
# >**NEWOffTopic**: Do you think Stack Overflow should relax restrictions on what is considered “off-topic”?
# >
# >>***No***
# >>*Not sure*
# >>***Yes***
# >
# >**NEWOnboardGood**	Do you think your company has a good onboarding process? (By onboarding, we mean the structured process of getting you settled in to your new role at a company)
# >
# >>***No***
# >>*Onboarding? What onboarding?*
# >>***Yes***
# >
# >**NEWOtherComms**	Are you a member of any other online developer communities?
# >
# >>**Yes**  ,
# >>*No*
# >
# >**NEWOvertime**	How often do you work overtime or beyond the formal time expectation of your job?
# >
# >>***Never***
# >>*Occasionally: 1-2 days per quarter but less than monthly*
# >>***Often: 1-2 days per week or more***
# >>*Rarely: 1-2 days per year or less*
# >>***Sometimes: 1-2 days per month but less than weekly***
# >
# >**NEWPurpleLink**	You search for a coding solution online and the first result link is purple because you already visited it. How do you feel?
# >>***Hello, old friend***
# >>*Indifferent*
# >>***Amused***
# >>*Annoyed*
# >
# >**MainBranch**  Which of the following options best describes you today? Here, by "developer" we mean "someone who writes code."
# >>***I am a developer by profession***  ,
# >>*I am a student who is learning to code*  ,
# >>***I am not primarily a developer, but I write code sometimes as part of my work***  ,
# >>*I code primarily as a hobby*  ,
# >>***I used to be a developer by profession, but no longer am***  ,
# >
# >**OpSys**	What is the primary operating system in which you work?
# >>***Berkeley Software Distribution (BSD)***
# >>*Linux-based*
# >>***MacOS***
# >>*Windows*
# >
# >**OrgSize**	Approximately how many people are employed by the company or organization you currently work for?
# >>***10,000 or more employees***
# >>*5,000 to 9,999 employees*
# >>***1,000 to 4,999 employees***
# >>*500 to 999 employees*
# >>***100 to 499 employees***
# >>*20 to 99 employees*
# >>***10 to 19 employees***
# >>*2 to 9 employees*
# >>***Just me - I am a freelancer, sole proprietor, etc.***
# >
# >**PurchaseWhat**	What level of influence do you, personally, have over new technology purchases at your organization?
# >>***I have little or no influence***
# >>*I have some influence*
# >>***I have a great deal of influence***
# >
# >**SOAccount**	Do you have a Stack Overflow account?
# >>***Yes***
# >>*No*
# >>***Not sure/can't remember***
# >
# >**SOComm**	Do you consider yourself a member of the Stack Overflow community?
# >>***Yes, somewhat***
# >>*No, not really*
# >>***Neutral***
# >>*Yes, definitely*
# >>***No, not at all***
# >>*Not sure*
# >
# >**SOPartFreq**	How frequently would you say you participate in Q&A on Stack Overflow? By participate we mean ask, answer,
# vote for, or comment on questions.
# >>***Less than once per month or monthly***
# >>*I have never participated in Q&A on Stack Overflow*
# >>***A few times per month or weekly***
# >>*A few times per week*
# >>***Daily or almost daily***
# >>*Multiple times per day*
# >
# >**SOVisitFreq**	How frequently would you say you visit Stack Overflow?
# >>***Less than once per month or monthly***
# >>*I have never participated in Q&A on Stack Overflow*
# >>***A few times per month or weekly***
# >>*A few times per week*
# >>***Daily or almost daily***
# >>*Multiple times per day*
# >
# >**SurveyEase**	How easy or difficult was this survey to complete?
# >>***Easy***
# >>*Neither easy nor difficult*
# >>***Difficult***
# >
# >**SurveyLength**	How do you feel about the length of the survey this year?
# >>***Appropriate in length***
# >>*Too long*
# >>***Too short***
# >
# >**Trans**	Are you transgender?
# >>***No***
# >>*Yes*
# >
# >**UndergradMajor**	What was your primary field of study?
# >>***Computer science, computer engineering, or software engineering***
# >>*Another engineering discipline (such as civil, electrical, mechanical, etc.)*
# >>***Information systems, information technology, or system administration***
# >>*A natural science (such as biology, chemistry, physics, etc.)*
# >>***Mathematics or statistics***
# >>*Web development or web design*
# >>***A business discipline (such as accounting, finance, marketing, etc.)***
# >>*A humanities discipline (such as literature, history, philosophy, etc.)*
# >>***A social science (such as anthropology, psychology, political science, etc.)***
# >>*Fine arts or performing arts (such as graphic design, music, studio art, etc.)*
# >>***I never declared a major***
# >>*A health science (such as nursing, pharmacy, radiology, etc.)*
# >
# >**WelcomeChange**	Compared to last year, how welcome do you feel on Stack Overflow?
# >>***Just as welcome now as I felt last year***
# >>*Somewhat more welcome now than last year*
# >>***A lot more welcome now than last year***
# >>*Somewhat less welcome now than last year*
# >>***A lot less welcome now than last year***
# >>*Not applicable - I did not use Stack Overflow last year*
# >
# >
#
#
# </font><font color='blue'> **Categorical variables with multiple options to choose** ***(select all that apply)***<br></font><font color='black'>
# ></font><font color='red'>We will be ignoring most of this variables in further analysis because of the large number of unique entries!
#
# </font><font color='black'>
# From this list we will only be using **``DevType`` , ``LanguageDesireNextYear`` , ``LanguageWorkedWith``**  and  ``MiscTechWorkedWith`` going forward<br></font><font color='black'>
#
#
# ``DatabaseDesireNextYear`` </font><font color='brown'> **(3193 unique entries)**:<br></font><font color='black'>
# >Which database environments have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the database and want to continue to do so, please check both boxes in that row.)
#
# ``DatabaseWorkedWith`` </font><font color='brown'> **(2808 unique entries)**:<br></font><font color='black'>
# >Which database environments have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the database and want to continue to do so, please check both boxes in that row.)
#
# **DevType**  (</font><font color='brown'> **(8269 unique entries)**:<br></font><font color='black'>
# >Which of the following describe you? Please select all that apply.
# >***We have created Boolean variables (i.e. new columns) for each choice (see below)***
#
# ``Ethnicity`` </font><font color='brown'> **(208 unique entries)**:<br></font><font color='black'>
# >Which of the following describe you, if any? Please check all that apply. If you prefer not to answer, you may leave this question blank.
#
# ``Gender`` (</font><font color='brown'> **(7 unique entries)**:<br></font><font color='black'>
# >Which of the following describe you, if any? Please check all that apply. If you prefer not to answer, you may leave this question blank.
#
# ``JobFactors`` (</font><font color='brown'> **(230 unique entries)**:<br></font><font color='black'>
# >Imagine that you are deciding between two job offers with the same compensation, benefits, and location. Of the following factors, which 3 are MOST important to you?
#
# **LanguageDesireNextYear** (</font><font color='brown'> **(16243 unique entries)**:<br></font><font color='black'>
# >Which programming, scripting, and markup languages have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the language and want to continue to do so, please check both boxes in that row.)
#
# **LanguageWorkedWith** (</font><font color='brown'> **(14256 unique entries)**:<br></font><font color='black'>
# >Which programming, scripting, and markup languages have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the language and want to continue to do so, please check both boxes in that row.)
# >***We have created Boolean variables (i.e. new columns) for each choice (see below)***
#
# ``NEWCollabToolsDesireNextYear`` (</font><font color='brown'> **(1277 unique entries)**:<br></font><font color='black'>
# >Which collaboration tools have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you worked with the tool and want to continue to do so, please check both boxes in that row.)
#
# ``NEWCollabToolsWorkedWith`` (</font><font color='brown'> **(1153 unique entries)**:<br></font><font color='black'>
# >Which collaboration tools have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you worked with the tool and want to continue to do so, please check both boxes in that row.)
#
# ``NEWJobHunt``(</font><font color='brown'> **(xxxx unique entries)**:<br></font><font color='black'>
# >In general, what drives you to look for a new job? Select all that apply.
#
# ``NEWJobHuntResearch`` (</font><font color='brown'> **(63 unique entries)**:<br></font><font color='black'>
# >When job searching, how do you learn more about a company? Select all that apply.
#
# ``NEWPurchaseResearch``	(</font><font color='brown'> **(63 unique entries)**:<br></font><font color='black'>
# >When buying a new tool or software, how do you discover and research available solutions? Select all that apply.
#
# ``NEWSOSites``	(</font><font color='brown'> **(61 unique entries)**:<br></font><font color='black'>
# >Which of the following Stack Overflow sites have you visited? Select all that apply.
#
# ``NEWStuck`` (</font><font color='brown'> **(444 unique entries)**:<br></font><font color='black'>
# >What do you do when you get stuck on a problem? Select all that apply.
#
# ``MiscTechDesireNextYear`` (</font><font color='brown'> **(5216 unique entries)**:<br></font><font color='black'>
# >Which other frameworks, libraries, and tools have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the framework and want to continue to do so, please check both boxes in that row.)
#
# **MiscTechWorkedWith** (</font><font color='brown'> **(2730 unique entries)**:<br></font><font color='black'>
# >Which other frameworks, libraries, and tools have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the framework and want to continue to do so, please check both boxes in that row.)
# >***We have created Boolean variables (i.e. new columns) for each choice (see below)***
#
# ``PlatformDesireNextYear`` (</font><font color='brown'> **(7471 unique entries)**:<br></font><font color='black'>
# >Which platforms have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the platform and want to continue to do so, please check both boxes in that row.)
#
# ``PlatformWorkedWith``	(</font><font color='brown'> **(6287 unique entries)**:<br></font><font color='black'>
# >Which platforms have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the platform and want to continue to do so, please check both boxes in that row.)
#
# ``Sexuality`` (</font><font color='brown'> **(14 unique entries)**:<br></font><font color='black'>
# >Which of the following describe you, if any? Please check all that apply. If you prefer not to answer, you may leave this question blank.
#
# ``WebframeDesireNextYear``	(</font><font color='brown'> **(3986 unique entries)**:<br></font><font color='black'>
# >Which web frameworks have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the framework and want to continue to do so, please check both boxes in that row.)
#
# ``WebframeWorkedWith``	(</font><font color='brown'> **(3789 unique entries)**:<br></font><font color='black'>
# >Which web frameworks have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the framework and want to continue to do so, please check both boxes in that row.)
#
#
# ></font><font color='blue'> **Boolean variables**<br></font><font
# >color='black'>
# >
# ></font><font color='blue'> (mapped from **DevType**) <br></font><font color='black'>
# >**System_administrator** ,
# >*Developer_embedded_applications_or_devices* ,
# >**Marketing_or_sales_professional** ,
# >*Data_or_business_analyst*  ,
# >**Academic_researcher**  ,
# >*Developer_backend*  ,
# >**Scientist**  ,
# >*Engineer_data* ,
# >**Developer_frontend**  ,
# >*Data_scientist_or_machine_learning_specialist*  ,
# >**Engineering_manager**  ,
# >*Developer_desktop_or_enterprise_applications*  ,
# >**Developer_game_or_graphics**  ,
# >*Designer*  ,
# >**DevOps_specialist**  ,
# >**Developer_mobile**  ,
# >*Engineer_site_reliability*  ,
# >**Developer_QA_or_test**  ,
# >*Senior_executive_VP*  ,
# >**Database_administrator**  ,
# >*Educator*  ,
# >**Product_manager**  ,
# >**Developer_fullstack**
# >
# >
# ></font><font color='blue'> (mapped from **LanguageWorkedWith**) <br></font><font color='black'>
# >**Assembly;**  ,
# >*Bash/Shell/PowerShell;*  ,
# >**C;**  ,
# >*C#;*  ,
# >**C++;**  ,
# >*Dart;*  ,
# >**Go;**  ,
# >*HTML/CSS;*  ,
# >**Haskell;**  ,
# >*Java;*  ,
# >**JavaScript;**  ,
# >*Julia;*  ,
# >**Kotlin;**  ,
# >*Objective-C;*  ,
# >**PHP;**  ,
# >*Perl;*  ,
# >**Python;**  ,
# >*R;*  ,
# >**Ruby;**  ,
# >*Rust;*  ,
# >**SQL;**   ,
# >*Scala;*  ,
# >**Swift;**   ,
# >*TypeScript;*  ,
# >**VBA;**
# >
# >
# ></font><font color='blue'> (mapped from **MiscTechWorkedWith**) <br></font><font color='black'>
# >**Node.js**  ,
# >*Ansible*  ,
# >**Cordova**  ,
# >*Pandas*  ,
# >**Flutter**  ,
# >*Apache Spark*  ,
# >**React Native**  ,
# >*Torch/PyTorch*  ,
# >**Keras**  ,
# >*Unity 3D*  ,
# >**Xamarin**  ,
# >*.NET Core*   ,
# >**.NET**  ,
# >*Teraform*  ,
# >**TensorFlow**  ,
# >*Puppet*  ,
# >**Chef**  ,
# >*Hadoop*  ,
# >**Unreal Engine**
# >
# >

# %% [markdown]
# <a id='numerical'></a>
# # Exploration of numerical variables

# %% [markdown]
# Let us start the exploration process by looking at the distribution of the numerical variables in the surveys.
#
# We will be using **Box-and-Whisker Plots**. A Box and Whisker Plot (or Box Plot) is a convenient way of visually displaying the data distribution through their quartiles. The lines extending parallel from the boxes are known as the “whiskers”, which are used to indicate variability outside the upper and lower quartiles.

# %% [markdown]
# ## **Age** (Definition)  </font><font color='grey'>**2020 survey**<br></font>
# >What is your age (in years)? If you prefer not to answer, you may leave this question blank.

# %%
sns.set(context='notebook', style='whitegrid', palette='deep', font='sans-serif', font_scale=1, rc=None)
plt.figure(figsize=[8, 5])
sns.boxplot(df2020_clean['Age'])
plt.xticks(rotation=0, fontsize=15)
plt.yticks(rotation=0, fontsize=15)
plt.show()
print(df2020_clean.Age.describe());
# Out:
# count    45446.000000
# mean        30.834111
# std          9.585392
# min          1.000000
# 25%         24.000000
# 50%         29.000000
# 75%         35.000000
# max        279.000000
# Name: Age, dtype: float64

# %% [markdown]
# The first step in constructing a **box-and-whisker plot** is to first find the median (Q2),the lower quartile (Q1)and the upper quartile (Q3) of a given set of data.
#
# </font><font color='green'>
# >### The median age of the respondants in the 2020 survey is 29 and the average age is 31 years.
# >The lower quartile is 24 years and the upper quartile is 35 years. The middle half of a data set falls within the interquartile range. In a boxplot, the **interquartile range (IQR)** is represented by the width of the box (Q3 minus Q1).
# <br></font><font color='black'>

# %%
df2020_clean[df2020_clean['Age'] > 100]
# Out:
#        Respondent                      MainBranch Hobbyist    Age  Age1stCode  \
# 14375       14419  I am a developer by profession      Yes  279.0        16.0
#
#       CompFreq  CompTotal  ConvertedComp      Country   CurrencyDesc  ...    \
# 14375   Yearly    49000.0        52968.0  Netherlands  European Euro  ...
#
#        Perl; Python;     R;  Ruby;  Rust;   SQL; Scala; Swift; TypeScript;  \
# 14375  False   False  False  False  False  False  False  False       False
#
#         VBA;
# 14375  False
#
# [1 rows x 126 columns]

# %% [markdown]
# Apparently, a dutch developer claims to be born around 1740 AD (Age 279) and to started coding around 1756 AD (Beginning of Seven Years' War in Europe). Nevertheless, the **whiskers** of the boxplot (i.e. the vertical lines extending to the most extreme, non-outlier data points) show that only a small fraction of respondants are over the age of 50. **A small number of outliers do not distort the major takeaway from this variable.**

# %% [markdown]
# ## **Age1stCode** (Definition)  </font><font color='grey'>**2020 survey**<br></font>
# >At what age did you write your first line of code or program? (e.g., webpage, Hello World, Scratch project)

# %%
sns.set(context='notebook', style='whitegrid', palette='deep', font='sans-serif', font_scale=1, rc=None)
plt.figure(figsize=[8, 5])
sns.boxplot(df2020_clean['Age1stCode'])
plt.xticks(rotation=0, fontsize=15)
plt.yticks(rotation=0, fontsize=15)
plt.show()
print(df2020_clean.Age1stCode.describe());
# Out:
# count    57900.000000
# mean        15.410121
# std          5.289951
# min          4.000000
# 25%         12.000000
# 50%         15.000000
# 75%         18.000000
# max         85.000000
# Name: Age1stCode, dtype: float64

# %% [markdown]
# >### </font><font color='green'>Most developers started coding in their teens. <br></font><font color='black'>

# %% [markdown]
# ## **YearsCode** (Definition)  </font><font color='grey'>**2020 survey**<br></font>
# >Including any education, how many years have you been coding in total?

# %%
sns.set(context='notebook', style='whitegrid', palette='deep', font='sans-serif', font_scale=1, rc=None)
plt.figure(figsize=[8, 5])
sns.boxplot(df2020_clean['YearsCode'])
plt.xticks(rotation=0, fontsize=15)
plt.yticks(rotation=0, fontsize=15)
plt.show()
print(df2020_clean.YearsCode.describe());
# Out:
# count    57684.000000
# mean        12.713135
# std          9.699281
# min          0.500000
# 25%          6.000000
# 50%         10.000000
# 75%         17.000000
# max         50.000000
# Name: YearsCode, dtype: float64

# %% [markdown]
#  </font><font color='green'>
# >### The median coding experiance of the respondants in the 2020 survey is 10 years.
# >The Interquartile range (IQR) is 6 to 17 years.
# <br></font><font color='black'>

# %% [markdown]
# ## **YearsCodePro** (Definition)  </font><font color='grey'>**2020 survey**<br></font>
# >NOT including education, how many years have you coded professionally (as a part of your work)?

# %%
sns.set(context='notebook', style='whitegrid', palette='deep', font='sans-serif', font_scale=1, rc=None)
plt.figure(figsize=[8, 5])
sns.boxplot(df2020_clean['YearsCodePro'])
plt.xticks(rotation=0, fontsize=15)
plt.yticks(rotation=0, fontsize=15)
plt.show()
print(df2020_clean.YearsCodePro.describe());
# Out:
# count    46349.000000
# mean         8.514358
# std          7.875942
# min          0.500000
# 25%          3.000000
# 50%          6.000000
# 75%         12.000000
# max         50.000000
# Name: YearsCodePro, dtype: float64

# %% [markdown]
#  </font><font color='green'>
# >### Respondants in the 2020 survey have a median professional coding experiance of 6 years.
# >Interquartile range (IQR) is between 3 to 12 years. Very few developers have been coding professionally for more than 25 years.
# <br></font><font color='black'>

# %% [markdown]
# ## WorkWeekHrs (Definition)  </font><font color='grey'>**2020 survey**<br></font>
# >On average, how many hours per week do you work? Please enter a whole number in the box.

# %%
sns.set(context='notebook', style='whitegrid', palette='deep', font='sans-serif', font_scale=1, rc=None)
plt.figure(figsize=[8, 5])
sns.boxplot(df2020_clean['WorkWeekHrs'])
plt.xticks(rotation=0, fontsize=15)
plt.yticks(rotation=0, fontsize=15)
plt.xlim([20, 60])
plt.show()
print(df2020_clean.WorkWeekHrs.describe());
# Out:
# count    41151.000000
# mean        40.782174
# std         17.816383
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         44.000000
# max        475.000000
# Name: WorkWeekHrs, dtype: float64

# %% [markdown]
#  </font><font color='green'>
# >### The median respondants in the 2020 survey works 40 hours a week.
# >Interquartile range (IQR) is between 40 to 43 hours.
# <br></font><font color='black'>

# %% [markdown]
# <a id='question0'></a>
# ## Research Question No.0
#
# >What is the distribution of salaries ?
# >

# %% [markdown]
# ## **CompTotal** (Definition)  </font><font color='grey'>**2020 survey**<br></font>
#
# >What is your current total compensation (salary, bonuses, and perks, before taxes and deductions), in CurrencySymbol? Please enter a whole number in the box below, without any punctuation. If you are paid hourly, please estimate an equivalent weekly, monthly, or yearly salary. If you prefer not to answer, please leave the box empty.

# %%
sns.set(context='notebook', style='whitegrid', palette='deep', font='sans-serif', font_scale=1, rc=None)
plt.figure(figsize=[8, 5])
sns.boxplot(df2020_clean['CompTotal'])
plt.xticks(rotation=0, fontsize=15)
plt.yticks(rotation=0, fontsize=15)
plt.xlim([0, 300000])
plt.title("All Recipients (2020 Survey)\n 'What is your current total compensation (in local currency)'");
plt.show()

# %% [markdown]
# The distribution of `CompTotal` doesn't give us much economic inside, because saleries are denominated in USD,EUR,GBP and other currencies with different values.
#
# Therefore, we filter for devolopers from the United States.

# %%
sns.set(context='notebook', style='whitegrid', palette='deep', font='sans-serif', font_scale=1, rc=None)
plt.figure(figsize=[8, 5])
sns.boxplot(df2020_clean[df2020_clean.Country == 'United States']['CompTotal'])
plt.xticks(rotation=0, fontsize=15)
plt.yticks(rotation=0, fontsize=15)
plt.xlim([0, 300000])
plt.title("United States (2020 Survey)\n 'What is your current total compensation (in USD)'");
plt.show()
print(df2020_clean[df2020_clean.Country == 'United States']['CompTotal'].describe());
# Out:
# count     8.171000e+03
# mean     1.359823e+243
# std                inf
# min       0.000000e+00
# 25%       8.000000e+04
# 50%       1.100000e+05
# 75%       1.500000e+05
# max      1.111111e+247
# Name: CompTotal, dtype: float64

# %% [markdown]
#  </font><font color='green'>
# >### For developers working in the United States, the median salery is USD 110,000
# >### and 2.5% of developers in the United States earn more the USD 250,000 annaully.
# >
# >Interquartile range (IQR) is USD 80,000 to USD 150,000 .
#
# <br></font><font color='black'>
# The whisker of this boxplot (i.e. the vertical lines extending to the most extreme, non-outlier data points) shows that 97.5% of the distribution are below USD 250,000 .
#
# Let us verify the last statement.

# %%
(df2020_clean[df2020_clean.Country == 'United States']['CompTotal'] > 250000).sum() /  \
    df2020_clean[df2020_clean.Country == 'United States'].shape[0]
# Out:
# 0.025583446948432113

# %% [markdown]
# ## **ConvertedComp** (Definition)  </font><font color='grey'>**2020 survey**<br></font>
# >Salary converted to annual USD salaries using the exchange rate on 2020-02-19, assuming 12 working months and 50 working weeks.

# %%
sns.set(context='notebook', style='whitegrid', palette='deep', font='sans-serif', font_scale=1, rc=None)
plt.figure(figsize=[8, 5])
sns.boxplot(df2020_clean['ConvertedComp'])
plt.xticks(rotation=0, fontsize=15)
plt.yticks(rotation=0, fontsize=15)
plt.xlim([0, 250000])
plt.title("All Recipients (2020 Survey) \n Salary converted to annual USD salaries using the exchange rate on 2020-02-19");
plt.show()
print(df2020_clean.ConvertedComp.describe());
# Out:
# count    3.475600e+04
# mean     1.037561e+05
# std      2.268853e+05
# min      0.000000e+00
# 25%      2.464800e+04
# 50%      5.404900e+04
# 75%      9.500000e+04
# max      2.000000e+06
# Name: ConvertedComp, dtype: float64

# %% [markdown]
#  </font><font color='green'>
# >### The median salary of all recipients of the 2020 survey converted to annual USD salaries is $54,000
# >Interquartile range (IQR) is between USD 25,000 to USD 95,000.
# <br></font><font color='black'>

# %% [markdown]
# Let us take **Germany** as an example. What is the distribution of saleries for developers in Germany?

# %%
sns.set(context='notebook', style='whitegrid', palette='deep', font='sans-serif', font_scale=1, rc=None)
plt.figure(figsize=[8, 5])
sns.boxplot(df2020_clean[df2020_clean.Country == 'Germany']['ConvertedComp'])
plt.xticks(rotation=0, fontsize=15)
plt.yticks(rotation=0, fontsize=15)
plt.xlim([0, 300000])
plt.title("GERMANY (2020 Survey)\n Salary converted to annual USD salaries using the exchange rate on 2020-02-19");
plt.show()
print(df2020_clean[df2020_clean.Country == 'Germany']['ConvertedComp'].describe());
# Out:
# count    2.311000e+03
# mean     9.250865e+04
# std      1.445045e+05
# min      2.400000e+01
# 25%      4.864400e+04
# 50%      6.269700e+04
# 75%      7.972250e+04
# max      1.200000e+06
# Name: ConvertedComp, dtype: float64

# %% [markdown]
#  </font><font color='green'>
# >### The median salary of German developers in the 2020 survey converted to USD salaries is $63,000 annually.
# >Interquartile range (IQR) is between USD 48,000 to USD 78,000. About 2.5 percent eran more than USD 120,000 per year.
# <br></font><font color='black'>

# %% [markdown]
# <a id='exploration'></a>
# # Exploration of categorical variables

# %% [markdown]
# ## **Country** (Definition)  </font><font color='grey'>**2018 and 2020 survey**<br></font>
# >Where do you live?

# %%
country_vals2018 = df2018.Country.value_counts()#Provide a pandas series of the counts for each unique entry (i.e. countries)

country_allocation2018 = (country_vals2018[:20]/df2018.shape[0])

country_allocation2018.plot(kind="barh");
plt.title("2018 Survey 'Where do you live?'\nTop 20 countries");

# %%
country_vals2020 = df2020.Country.value_counts()# Provide a pandas series of the counts for each unique entry

country_allocation2020 = (country_vals2020[:20]/df2020.shape[0])

country_allocation2020.plot(kind="barh");
plt.title("2020 Survey 'Where do you live?'\nTop 20 countries");

# %% [markdown]
#  </font><font color='green'>
# ### For both the 2018 and 2020 surveys,
# </font><font color='green'>
# >about ***20 percent*** of recipients come from the **United States**,
# >
# >about ***13 percent*** come from **India**,
# >
# >about  ***6 percent*** from the **United Kingdom** and **Germany**, respectively,
# >
# >and ***3 percent*** from **Canada**.
#
# >**France**, *Brazil* , **Russian Federation**, *Poland*, **Australia**, *Austria*, **Netherlands**, *Spain*, **Italy**, *Sweden*, **Parkistan**, *Turkey*, **Bangladesh** and **Switzerland** are in the Stack Overflow 2020 Survey Top 20 list of both the 2018 and 2020 surveys as well.
#
# Surprisingly, **China** dropped out of the Top 20 list in the 2020 survey, being replaced by **Romania**. Other countries of **The G20 (or Group of Twenty)** that do not appear in the Top 20 are Argentina, Indonesia, Japan, Mexico, Saudi Arabia, South Africa and South Korea.
# <br></font><font color='black'>
# Collectively, the G20 economies account for around 90% of the gross world product (GWP), 80% of world trade (or, if excluding EU intra-trade, 75%), two-thirds of the world population, and approximately half of the world land area.
# https://en.wikipedia.org/wiki/G20
#
# As of 2020 there are 20 members of the G20 group: Argentina, Australia, Brazil, Canada, China, the European Union, France, Germany, India, Indonesia, Italy, Japan, Mexico, Russia, Saudi Arabia, South Africa, South Korea, Turkey, the United Kingdom, and the United States. Spain is a permanent guest invitee.

# %% [markdown]
# ## **EdLevel** (Definition)  </font><font color='grey'>**2020 survey**<br></font>
# >Which of the following best describes the highest level of formal education that you have completed?

# %%
EdLevel_vals = df2020_clean.EdLevel.value_counts()#Provide a pandas series of the counts for each unique entry

(EdLevel_vals/df2020_clean.shape[0]).plot(kind="barh");
plt.title("2020 Survey \nHighest level of formal education that you have completed?");

# %% [markdown]
#  </font><font color='green'>
# >### Most developers in the 2020 survey have studied at a university.
# >About 2/3 of recipients have an academic degree (bachelor's, master's or doctoral degrees) or professional degree. However, many developers have successfully entered the field without starting or completing an academic degree first.
# <br></font><font color='black'>

# %% [markdown]
# ## **UndergradMajor** (Definition)  </font><font color='grey'>**2018 and 2020 survey**<br></font><font color='black'>
# >What was your primary field of study?

# %%
UndergradMajor_vals2018 = df2018.UndergradMajor.value_counts()#Provide a pandas series of the counts for each unique entry


(UndergradMajor_vals2018/df2018.shape[0]).plot(kind="barh");
plt.title("2018 Survey What was your primary field of study?");

# %%
UndergradMajor_vals2020 = df2020_clean.UndergradMajor.value_counts()# Provide a pandas series of the counts 
                                                                    # for each unique entry

(UndergradMajor_vals2020/df2020_clean.shape[0]).plot(kind="barh");
plt.title("2020 Survey \nWhat was your primary field of study?");

# %% [markdown]
#  </font><font color='green'>
# >### Most developers in both the 2018 and 2020 surveys have majored in a Computer science, Engineering or Information technology subject.
# <br></font><font color='black'>

# %% [markdown]
# ## **Employment** (Definition)  </font><font color='grey'>**2020 survey**<br></font><font color='black'>
# >Which of the following best describes your current employment status?

# %%
Employment_vals = df2020_clean.Employment.value_counts()#Provide a pandas series of the counts for each unique entry


(Employment_vals/df2020_clean.shape[0]).plot(kind="barh");
plt.title("2020 Survey \nWhich of the following best describes your current employment status?");

# %% [markdown]
#  </font><font color='green'>
# >### Most developers in the 2020 survey are full-time employed, students or work self-employed.
# >Only a fraction of respondants is not employed or retired.
# <br></font><font color='black'>

# %% [markdown]
# ## **JobSat** (Definition)  </font><font color='grey'>**2020 survey**<br></font><font color='black'>
# >How satisfied are you with your current job? (If you work multiple jobs, answer for the one you spend the most hours on.)

# %%
JobSat_vals = df2020_clean.JobSat.value_counts() # Provide a pandas series of the counts for each unique entry


(JobSat_vals/df2020_clean.shape[0]).plot(kind="barh");
plt.title("2020 Survey \nHow satisfied are you with your current job?");

# %% [markdown]
#  </font><font color='green'>
# >### Only half of the developers in the 2020 survey are satisfied with their current job.
#
#
# <br></font><font color='black'>

# %% [markdown]
# **Agile Project Management** methodologies are widespread in software development. The 2020 survey has two new questions dealing with **DevOps**.
#
# >*"DevOps is a set of practices that combines software development (Dev) and IT operations (Ops). It aims to shorten the systems development life cycle and provide continuous delivery with high software quality.DevOps is complementary with Agile software development; several DevOps aspects came from Agile methodology."*
# >https://en.wikipedia.org/wiki/DevOps

# %% [markdown]
# ## **NEWDevOps** (Definition)  </font><font color='grey'>**2020 survey**<br></font><font color='black'>
# > Does your company have a dedicated DevOps person?
# >

# %%
DevOps_vals = df2020_clean.NEWDevOps.value_counts()#Provide a pandas series of the counts for each unique entry


(DevOps_vals/df2020_clean.shape[0]).plot(kind="barh");
plt.title("2020 Survey \nDoes your company have a dedicated DevOps person?");

# %% [markdown]
#  </font><font color='green'>
# >### About half of the respondants in the 2020 survey said that their company has a dedicated DevOps person.
#
#
# <br></font><font color='black'>

# %% [markdown]
# ## **NEWDevOpsImpt** (Definition)   </font><font color='grey'>**2020 survey**<br></font><font color='black'>
# >How important is the practice of DevOps to scaling software development?
# >

# %%
DevOpsImpt_vals = df2020_clean.NEWDevOpsImpt.value_counts()#Provide a pandas series of the counts for each unique entry


(DevOpsImpt_vals/df2020_clean.shape[0]).plot(kind="barh");
plt.title("2020 Survey \nHow important is the practice of DevOps to scaling software development?");

# %% [markdown]
#  </font><font color='green'>
# >### Most developers in the 2020 survey concider DevOps important.
#
# <br></font><font color='black'>

# %% [markdown]
# In the 2018 survey there is one question asking specifically about project management methodologies.

# %% [markdown]
# <a id='methodology'></a>
#
# ## **Methodology** (Definition)  </font><font color='grey'>**2018 survey only**<br></font><font color='black'>
# >Which Project Management Methodologies Do Developers Use?

# %%
df2018.Methodology.nunique()
# Out:
# 480

# %% [markdown]
# There is a large number of unique entries created by various combination possibilities of options to pick for this question.
#
# Let us find the project management methodologies (i.e. options) to choose from.

# %%
ProjectManagement = df2018_clean.Methodology.dropna(axis=0).unique()

txt = []

for i in range(len(ProjectManagement)):
    name = (ProjectManagement[i].split(";"))
    txt.append(name)

ProjectManagement = set(list(chain.from_iterable(txt))) # The data type SET makes sure that 
                                              #  project management types only appear once

ProjectManagement # print the set of project management methodologies
# Out:
# {'Agile',
#  'Evidence-based software engineering',
#  'Extreme programming (XP)',
#  'Formal standard such as ISO 9001 or IEEE 12207 (aka “waterfall” methodologies)',
#  'Kanban',
#  'Lean',
#  'Mob programming',
#  'PRINCE2',
#  'Pair programming',
#  'Scrum'}

# %% [markdown]
# The variable **`df_2018`** ``Methodology`` has **n = 10** options to choose from (e.g. ``[Agile]``, ``[Scrum]``) and respondants can **tick all that apply**. Therefore, the number of ***possible*** unique entries is\begin{equation} 2^n - 1 = 1023\end{equation}
#
#
# What is the ***observed*** number of unique entries?

# %%
df2018.Methodology.nunique() #  show no. of unique entries in the column
# Out:
# 480

# %% [markdown]
# Respondants provide 480 different combinations of the 10 options provided in the multiple choice question of **`df_2018`** ``Methodology``. Therefore, about half of the combination possibilities were indeed used. Apparently, project management methodologies can be combined in many ways.
#
# We would like to print a diagram of the share of the different project management methodologies. However, we need to define a **helper function** to count the number of occurrence of each methodology.

# %%
# Helper function to count the number of occurrence taken from a lecture of the Udacity Data Science Nanodegree program

def total_count(df, col1, col2, look_for):
    '''
    INPUT:
    df - the pandas dataframe you want to search
    col1 - the column name you want to look through
    col2 - the column you want to count values for
    look_for - a list of strings you want to search for in each row of df[col]
    
    OUTPUT:
    new_df - a dataframe of each look_for with the count of how often it shows up
    '''
    from collections import defaultdict
    new_df = defaultdict(int)
    for val in look_for:
        for idx in range(df.shape[0]):
            if val in df[col1][idx]:
                new_df[val] += int(df[col2][idx])
    new_df = pd.DataFrame(pd.Series(new_df)).reset_index()
    new_df.columns = [col1, col2]
    new_df.sort_values('count', ascending = False, inplace = True)
    return new_df

# %% [markdown]
# Let us print a nice looking chart:

# %%
pm_methodes =  list(ProjectManagement)

methodology = df2018_clean['Methodology'].value_counts().reset_index()
methodology.rename(columns={'index': 'pm_methodology', 'Methodology': 'count'}, inplace=True)
methodology_df = total_count(methodology, 'pm_methodology', 'count', pm_methodes)
methodology_df.set_index('pm_methodology', inplace=True)
    
pm_methodes_share = (methodology_df/df2018_clean.Methodology.shape)    

ax = pm_methodes_share.plot(kind='barh', figsize=(8, 10), color='#86bf91', zorder=2, width=0.85)

  # Despine
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)


  # Draw vertical axis lines
vals = ax.get_xticks()
for tick in vals:
    ax.axvline(x=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

  # Set x-axis label
ax.set_xlabel("% of respondents  (2018 Survey) ", labelpad=20, weight='bold', size=15)

  # Set y-axis label
ax.set_ylabel("PM Methodology", labelpad=20, weight='bold', size=15)


plt.title('Project Management \nWhich Methodologies Do Developers Use?', weight='bold', size=20);
plt.show()

# %% [markdown]
# </font><font color='green'>
# >### Agile and Scrum are the most popular project management methodologies for software developers.
# >Only a fraction of respondants use traditional project management methodologies (aka 'waterfall' methodologies). However, the Kanban methodology originally developed in manufacturing (Toyota) is popular with software developers as well.
# <br></font><font color='black'>

# %% [markdown]
# ## **PurchaseWhat**	(Definition)  </font><font color='grey'>**2020 survey**<br></font><font color='black'>
# >What level of influence do you, personally, have over new technology purchases at your organization?
# >

# %%
PurchaseWhat_vals = df2020_clean.PurchaseWhat.value_counts()#Provide a pandas series of the counts for each unique entry
(PurchaseWhat_vals/df2020_clean.shape[0]).plot(kind="barh");
plt.title("2020 Survey\nWhat level of influence do you, personally, have over new technology purchases at your organization?");

# %% [markdown]
# </font><font color='green'>
# >### About half of the respondants in the 2020 survey say that they can influence the technology purchases of their organisation.
#
#
# <br></font><font color='black'>

# %% [markdown]
# ## **SOAccount** (Definition)  </font><font color='grey'>**2020 survey**<br></font><font color='black'>
# >Do you have a Stack Overflow account?

# %%
SOAccount_vals = df2020_clean.SOAccount.value_counts()#Provide a pandas series of the counts for each unique entry
(SOAccount_vals/df2020_clean.shape[0]).plot(kind="barh");
plt.title("2020 Survey\nDo you have a Stack Overflow account?");

# %% [markdown]
# </font><font color='green'>
# >### Most respondants in the 2020 survey have a Stack Overflow account.
#
# <br></font><font color='black'>

# %% [markdown]
# ## **SOComm**	(Definition)  </font><font color='grey'>**2020 survey**<br></font><font color='black'>
# >Do you consider yourself a member of the Stack Overflow community?

# %%
SOComm_vals = df2020_clean.SOComm.value_counts()#Provide a pandas series of the counts for each unique entry
(SOComm_vals/df2020_clean.shape[0]).plot(kind="barh");
plt.title("2020 Survey\n Do you consider yourself a member of the Stack Overflow community?");

# %% [markdown]
# </font><font color='green'>
# >### About 40% of the respondants in the 2020 survey concider themselfs members of the Stack Overflow community.
#
# <br></font><font color='black'>

# %% [markdown]
# ## **SOPartFreq**	(Definition)  </font><font color='grey'>**2020 survey**<br></font><font color='black'>
# >How frequently would you say you participate in Q&A on Stack Overflow? By participate we mean ask, answer,
# vote for, or comment on questions.
# >

# %%
SOPartFreq_vals = df2020_clean.SOPartFreq.value_counts()#Provide a pandas series of the counts for each unique entry
(SOPartFreq_vals/df2020_clean.shape[0]).plot(kind="barh");
plt.title("2020 Survey\nHow frequently would you say you participate in Q&A on Stack Overflow?\n By participate we mean ask, answer, vote for, or comment on questions.");

# %% [markdown]
# </font><font color='green'>
# >### About half of the respondants in the 2020 survey actively participate in Q&A on Stack Overflow.
#
# <br></font><font color='black'>

# %% [markdown]
# ## **SOVisitFreq** (Definition)	  </font><font color='grey'>**2030 survey**<br></font><font color='black'>
# >How frequently would you say you visit Stack Overflow?

# %%
SOVisitFreq_vals = df2020_clean.SOVisitFreq.value_counts()#Provide a pandas series of the counts for each unique entry
(SOVisitFreq_vals/df2020_clean.shape[0]).plot(kind="barh");
plt.title("2020 Survey\nHow frequently would you say you visit Stack Overflow?");

# %% [markdown]
# </font><font color='green'>
# >### Most respondants in the 2020 survey frequently visit the Stack Overflow webside.
#
# <br></font><font color='black'>

# %% [markdown]
# ## **NEWPurpleLink** (Definition)  </font><font color='grey'>**2020 survey**<br></font><font color='black'>
# >You search for a coding solution online and the first result link is purple because you already visited it. How do you feel?

# %%
PurpleLink_vals = df2020_clean.NEWPurpleLink.value_counts()#Provide a pandas series of the counts for each unique entry
(PurpleLink_vals/df2020_clean.shape[0]).plot(kind="barh");
plt.title("2020 Survey\nYou search for a coding solution online and the first result link is purple\
\nbecause you already visited it. How do you feel?");

# %% [markdown]
# </font><font color='green'>
# >### Most respondants in the 2020 survey are not annoyed if they look up the same problem multiple times on the Stack Overflow webside.
#
# <br></font><font color='black'>

# %% [markdown]
# ## **SurveyLength** (Definition)  </font><font color='grey'>**2020 survey**<br></font><font color='black'>
# >How do you feel about the length of the survey this year?

# %%
SurveyLength_vals = df2020_clean.SurveyLength.value_counts()#Provide a pandas series of the counts for each unique entry
(SurveyLength_vals/df2020_clean.shape[0]).plot(kind="barh");
plt.title("2020 Survey\nHow do you feel about the length of the survey this year?");

# %% [markdown]
# </font><font color='green'>
# >### About 15 percent of the respondants in the 2020 survey concider the survey too long.
#
# <br></font><font color='black'>

# %% [markdown]
# ## **Trans** (Definition) </font><font color='grey'>**2020 survey**<br></font><font color='black'>
# >Are you transgender?
# >

# %%
Trans_vals = df2020_clean.Trans.value_counts()#Provide a pandas series of the counts for each unique entry
(Trans_vals/df2020_clean.shape[0]).plot(kind="barh");
plt.title("2020 Survey\nAre you transgender");
(Trans_vals/df2020_clean.shape[0])
# Out:
# No     0.758148
# Yes    0.007353
# Name: Trans, dtype: float64

# %% [markdown]
# </font><font color='green'>
# >### About 0.8 percent of respondants in the 2020 survey describe themself as transgender.
#
# <br></font><font color='black'>

# %% [markdown]
# ## **WelcomeChange**	(Definition) </font><font color='grey'>**2020 survey**<br></font><font color='black'>
# >Compared to last year, how welcome do you feel on Stack Overflow?
# >

# %%
WelcomeChange_vals = df2020_clean.WelcomeChange.value_counts()#Provide a pandas series of the counts for each FormalEducation status
(WelcomeChange_vals/df2020_clean.shape[0]).plot(kind="barh");
plt.title("2020 Survey\nCompared to last year, how welcome do you feel on Stack Overflow?");

# %% [markdown]
# </font><font color='green'>
# >### Most respondants in the 2020 survey feel welcome on the Stack Overflow webside.
#
# <br></font><font color='black'>

# %% [markdown]
# Let us exlore the different **Developer Roles** performed by the respondants of the 2020 survey.
#
# We will be using the dataframe **`df2020_DevType`** that consists of the column `DevType` and the 23 boolean variables mapped from **`df2020`** `DevType`.

# %%
df2020_DevType
# Out:
#                                                  DevType  Academic_researcher  \
# 0      Developer, desktop or enterprise applications;...                False
# 1                Developer, full-stack;Developer, mobile                False
# 5        Designer;Developer, front-end;Developer, mobile                False
# 6      Developer, back-end;Developer, front-end;Devel...                False
# 7      Developer, back-end;Developer, desktop or ente...                False
# 8                                  Developer, full-stack                False
# 9      Database administrator;Developer, full-stack;D...                False
# 10     Developer, back-end;Developer, desktop or ente...                False
# 11                         Designer;Developer, front-end                False
# 12                          Designer;Developer, back-end                False
# 13     Developer, desktop or enterprise applications;...                False
# ...

# %% [markdown]
# The pandas series **DevType_share** was defined before.

# %%
DevType_share
# Out:
# Marketing_or_sales_professional                  0.013004
# Senior_executive_VP                              0.026737
# Engineer_site_reliability                        0.039295
# Scientist                                        0.042252
# Product_manager                                  0.050577
# Engineering_manager                              0.055175
# Developer_game_or_graphics                       0.056492
# Educator                                         0.059307
# Academic_researcher                              0.071947
# Engineer_data                                    0.075714
# Developer_QA_or_test                             0.079947
# Data_scientist_or_machine_learning_specialist    0.080778
# Data_or_business_analyst                         0.081507
# Developer_embedded_applications_or_devices       0.096212
# System_administrator                             0.106178
# Designer                                         0.107778
# ...

# %% [markdown]
# Let us produce a nice looking chart for the share of each developer role.

# %%
# DevType_share was defined before 

ax = DevType_share.plot(kind='barh', figsize=(8, 10), color='#36bf99', zorder=2, width=0.85)

  # Despine
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

  # Switch off ticks
ax.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

  # Draw vertical axis lines
vals = ax.get_xticks()
for tick in vals:
    ax.axvline(x=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

  # Set x-axis label
ax.set_xlabel("% of respondents (2020 Survey) ", labelpad=20, weight='bold', size=15)

  # Set y-axis label
ax.set_ylabel("Developer Type", labelpad=20, weight='bold', size=15)

plt.title('Stack Overflow 2020 Developer Survey\nWhich of the following describe you? Please select all that apply.', weight='bold', size=20);
plt.show()     
print('# of respondants: ', df2020_DevType.shape[0])
print('On average developers have',round(sum(DevType_share),1), 'roles.')
# Out:
# # of respondants:  49370
# On average developers have 3.2 roles.

# %% [markdown]
# The **49,370 respondants** could choose more than option in this question (i.e. select all that apply). On average, developers picked 3.2 developer types to describe their roles. We're interested in the approx. 8 percent of respondants who picked the `[Data_scientist_or_machine_learning_specialist]`  option.
#
# <a id='question1'></a>
# ## Research Question No.1
#
# >What *additional* developer roles do ``[Data_scientist_or_machine_learning_specialist]`` perform?

# %% [markdown]
# - Create a new pandas series that consists of the mean values of each of the 32 columns with boolean type mapped from the variable **`df2020`** `DevType` ***and*** take only observations where `[Data_scientist_or_machine_learning_specialist]` == True .

# %%
df2020_DSML = df2020_DevType[df2020_DevType['Data_scientist_or_machine_learning_specialist']].mean().sort_values()
df2020_DSML
# Out:
# Marketing_or_sales_professional                  0.030592
# Senior_executive_VP                              0.054915
# Engineer_site_reliability                        0.057924
# Developer_game_or_graphics                       0.077232
# Engineering_manager                              0.081244
# Product_manager                                  0.082247
# Developer_QA_or_test                             0.085256
# Designer                                         0.113842
# Educator                                         0.122869
# Developer_embedded_applications_or_devices       0.128385
# System_administrator                             0.133902
# DevOps_specialist                                0.141424
# Developer_mobile                                 0.142678
# Database_administrator                           0.188816
# Developer_desktop_or_enterprise_applications     0.194082
# Developer_frontend                               0.223420
# ...

# %% [markdown]
# Let us create a nice looking chart.

# %%
ax = df2020_DSML.plot(kind='barh', figsize=(8, 10), color='#36bf99', zorder=2, width=0.85)

  # Despine
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

  # Switch off ticks
ax.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

  # Draw vertical axis lines
vals = ax.get_xticks()
for tick in vals:
    ax.axvline(x=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

  # Set x-axis label
ax.set_xlabel("% of respondents who described themselves as DS/ML Specialist (2020 Survey) ", labelpad=20, weight='bold', size=15)

  # Set y-axis label
ax.set_ylabel("Developer Type", labelpad=20, weight='bold', size=15)


plt.title('Data Scientist / Machine Learning Specialist\nWhich of the following describe you? Please select all that apply.\n'\
          , weight='bold', size=20);
plt.xlim([0, 1])
plt.show()     
print('# of ', df2020_clean[df2020_clean['Data_scientist_or_machine_learning_specialist']].count().head(1))
print(df2020_DSML.tail().sort_values(ascending=False))
# Out:
# # of  Respondent    3988
# dtype: int64
# Data_scientist_or_machine_learning_specialist    1.000000
# Developer_backend                                0.472668
# Developer_fullstack                              0.371866
# Data_or_business_analyst                         0.325226
# Engineer_data                                    0.297894
# dtype: float64

# %% [markdown]
# In the 2020 developer survey, 3988 developers or **8.1 percent** of the survey respondants perform the role of Data Scientists or Machine Learning specialists. How many additional developer roles do they perform?

# %%
print('On average, Data Scientist/Machine Learning Specialist have',round(df2020_DSML.sum()-1,1), \
      'additional developer roles.')
# Out:
# On average, Data Scientist/Machine Learning Specialist have 3.8 additional developer roles.

# %% [markdown]
# </font><font color='green'>
# >### Data Scientist/Machine Learning Specialist frequently perform additional software developer roles as well.
# >Almost half are ``[Developer backend]`` and 37 % are ``[Developer fullstack]``.
#
# >Other popular developer roles performed are
# >
# >- ``[Data or business analyst]`` ( 33 %)
# >
# >- ``[Engineer data]`` ( 30 %).
# >
# >- About a third are ``[Academic researcher]`` or ``[Scientist]``
#
# <br></font><font color='black'>

# %% [markdown]
# <a id='question2'></a>
# ## Research Question No.2
#
# >What programming languages do **Data Scientist/Machine Learning Specialist** use?

# %% [markdown]
# - Create a new pandas series that consists of the mean values of each of the 25 columns with boolean type mapped from the variable **`df2020`** `LanguageWorkedWith` ***and*** take only observations where `[Data_scientist_or_machine_learning_specialist]` == True .

# %%
# Create a new pandas series 
DSML_languages = (df2020_clean[df2020_clean['Data_scientist_or_machine_learning_specialist']].mean().tail(25)).sort_values()
DSML_languages
# Out:
# Dart;                     0.033601
# Haskell;                  0.036610
# Objective-C;              0.038114
# Julia;                    0.042377
# Perl;                     0.044132
# Swift;                    0.046891
# Kotlin;                   0.059178
# Rust;                     0.062187
# Ruby;                     0.064193
# Assembly;                 0.075226
# Scala;                    0.083751
# VBA;                      0.093280
# Go;                       0.095537
# TypeScript;               0.139920
# PHP;                      0.180040
# C#;                       0.213390
# C;                        0.250502
# R;                        0.276329
# C++;                      0.297894
# Java;                     0.350552
# Bash/Shell/PowerShell;    0.395687
# HTML/CSS;                 0.482447
# JavaScript;               0.482698
# SQL;                      0.584504
# Python;                   0.783350
# dtype: float64

# %% [markdown]
# How many languages do Data Scientist/Machine Learning Specialist use on average?

# %%
DSML_languages.sum()
# Out:
# 5.212387161484454

# %%
ax = DSML_languages.plot(kind='barh', figsize=(8, 10), color='#36bf99', zorder=2, width=0.85)

  # Despine
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

  # Switch off ticks
ax.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

  # Draw vertical axis lines
vals = ax.get_xticks()
for tick in vals:
    ax.axvline(x=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

  # Set x-axis label
ax.set_xlabel("% of respondents who described themselves as DS/ML Specialist (2020 Survey) ", labelpad=20, weight='bold', size=15)

  # Set y-axis label
ax.set_ylabel("Programming Language", labelpad=20, weight='bold', size=15)

  # Format y-axis label
#ax.xaxis.set_major_formatter(StrMethodFormatter('{x:,g}'))

plt.title('Data Scientist / Machine Learning Specialist \nWhat Languages Do They Use?\n', weight='bold', size=20);
plt.show()     
print((df2020_clean[df2020_clean['Data_scientist_or_machine_learning_specialist']]).count().head(1))
print('\nOn average, Data Scientist/Machine Learning Specialists use',round(DSML_languages.sum(),1), \
      'programming, scripting, and markup languages.')
# Out:
# Respondent    3988
# dtype: int64
#
# On average, Data Scientist/Machine Learning Specialists use 5.2 programming, scripting, and markup languages.

# %% [markdown]
# </font><font color='green'>
# ## Data Scientist/Machine Learning Specialists##
# >**- Python** is by far the most popular programming language for Data Science and Machine Learning.
# >
# >- Structured Query Language **(SQL)** is used by 60 %
# >
# >- Half use the languages **HTML/CSS** and **JavaScript** for web development
# >
# >- 40 % use **Bash/Shell/PowerShell** for command line Interface.
# >
# >- 28 % use the **R language** for data analysis
# >
# >-  9 % use Visual Basic for Applications (**VBA**)
# >
# >- Already 4  % use **Julia** , a language that first appeared in 2012
#
# <br></font><font color='black'>

# %% [markdown]
# <a id='question3'></a>
# ## Research Question No.3
#
# >What is the correlation between technologies used by all respondants of the 2020 survey ?
# >
# >**MiscTechWorkedWith**:
# >Which other frameworks, libraries, and tools have you done extensive development work in over the past year?

# %% [markdown]
# Let us create a headmap to show the correlation between technologies used.

# %%
ig, ax = plt.subplots(figsize=(15,15))         # Sample figsize in inches

sns.heatmap(df2020_MiscTechWorkedWith.corr(), annot=True, fmt=".1f", linewidths=.5);

# %% [markdown]
# </font><font color='green'>
#
#
# ## Pairs of technologies that are highly correlated
#
#
# >***[developer platform for building many different types of applications]***
# >
# >>- There is a strong **correlation of 0.7** between `[.NET Core]` and `[.NET]`
# >
# >***[Machine Learning]***
# >
# >
# >>- `[Keras]` and `[TensorFlow]` (**correlation 0.6**)
# >>
# >>- `[Torch/PyTorch]` and `[Keras]` (**correlation 0.4**)
# >>
# >>- `[Torch/PyTorch]` and `[TensorFlow]` (**correaltion 0.4**).
# >>
# >
# >***[Big Data]***
# >
# >>- `[Apache Spark]` and `[Hadoop]` (**correlation 0.5**)
# >>
# >
# >***[Game Engines]***
# >
# >>- `[Utility 3D]` and `[Unreal Engine]` (**correaltion 0.4**).
# <br></font><font color='black'>

# %% [markdown]
# <a id='question4'></a>
# ## Research Question No.4
#
# >What technologies do **Data Scientist/Machine Learning Specialist** use?

# %% [markdown]
# - Create a new pandas series that consists of the mean values of each of the 19 columns with boolean type mapped from the variable **`df2020`** `MiscTechWorkedWith` ***and*** take only observations where `[Data_scientist_or_machine_learning_specialist]` == True .

# %%
# 
DSML_MiscTechWorkedWith = df2020_clean[df2020_clean['Data_scientist_or_machine_learning_specialist']].filter(
    [".NET" , "Puppet" ,"Cordova" , "Unreal Engine", "Node.js", "Pandas", "TensorFlow" ,       
     "React Native" , "Torch/PyTorch" ,  "Chef" , "Hadoop" , "Flutter" ,  
     "Apache Spark" , "Teraform", "Unity 3D" , "Keras" ,
     ".NET Core" , "Xamarin" , "Ansible" ], axis=1).mean().sort_values()

# %% [markdown]
# The pandas series should show the percentage share of each technology.

# %%
DSML_MiscTechWorkedWith
# Out:
# Chef             0.020812
# Puppet           0.024323
# Unreal Engine    0.027583
# Xamarin          0.035858
# Cordova          0.037613
# Flutter          0.047894
# Teraform         0.051655
# Ansible          0.060933
# Unity 3D         0.066449
# React Native     0.072467
# Hadoop           0.129639
# .NET Core        0.134403
# Apache Spark     0.156971
# .NET             0.172016
# Torch/PyTorch    0.198345
# Node.js          0.256520
# Keras            0.272568
# TensorFlow       0.379388
# Pandas           0.500752
# dtype: float64

# %% [markdown]
# Let us create a nice looking chart.

# %%
ax = DSML_MiscTechWorkedWith.plot(kind='barh', figsize=(8, 10), color='#36bf99', zorder=2, width=0.85)

# Despine
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

  # Switch off ticks
ax.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

  # Draw vertical axis lines
vals = ax.get_xticks()
for tick in vals:
    ax.axvline(x=tick, linestyle='dashed', alpha=0.4, color='#ffffff', zorder=1)

  # Set x-axis label
ax.set_xlabel("% of respondents who described themselves as DS/ML Specialist (2020 Survey) ", labelpad=20, weight='bold', size=15)

  # Set y-axis label
ax.set_ylabel("Other Frameworks, Libraries, and Tools", labelpad=20, weight='bold', size=15)

  # Format y-axis label
#ax.xaxis.set_major_formatter(StrMethodFormatter('{x:,g}'))

plt.title('Data Scientist / Machine Learning Specialist \nMost Popular Technologies', weight='bold', size=20);
plt.show()    

print('On average DS/ML Specialists use ',round(sum(DSML_MiscTechWorkedWith),1), 'technologies.')
# Out:
# On average DS/ML Specialists use  2.6 technologies.

# %% [markdown]
# </font><font color='green'>
# >### The most popular technologies used by Data Scientist/Machine Learning Specialist are:
# >>**(1)** `[Pandas]` (50 %)
# >>
# >>**(2)** `[Tensorflow]` (38 %)
# >>
# >>**(3)** `[Keras]`(27 %)
# >>
# >>**(4)** `[Node.js]`(26 %)
# >>
# >>**(5)** `[Torch/PyTorch]`(20 %)
#
# >
# <br></font><font color='black'>

# %% [markdown]
# <a id='question5'></a>
# ## Research Question No.5
#
# >What is the correlation between languages used by all respondants of the 2020 survey ?
# >
# >**LanguageWorkedWith**:
# >Which programming, scripting, and markup languages have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the language and want to continue to do so, please check both boxes in that row.)

# %% [markdown]
# We will be using the dataframe **`df2020_LanguageWorkedWith`** that consists of the column `LanguageWorkedWith` and the 25 boolean variables mapped from **`df2020`**  `LanguageWorkedWith`.

# %%
ig, ax = plt.subplots(figsize=(15,15))         # Sample figsize in inches
#sns.heatmap(df1.iloc[:, 1:6:], annot=True, linewidths=.5, ax=ax)

sns.heatmap(df2020_LanguageWorkedWith.corr(), annot=True, fmt=".1f", linewidths=.5);

# %% [markdown]
# </font><font color='green'>
#
#
# ## Pairs of programming, scripting, and markup languages that are highly correlated
#
#
# >***[Web Design]***
# >
# >>There is a strong **correlation of 0.6** between `[HTML/CSS]` and `[JavaScript]`
# >
# >***[Language designers: Apple]***
# >
# >
# >>`[Objective-C]` and `[Swift]` (**correlation 0.5**)
# >>
# >
# >***[Using Assembly Language and C/C++]***
# >
# >>`[C]` and `[C++]` (**correlation 0.5**)
# >>
# >>`[C]` and `[Assembly]` (**correlation 0.4**).
# >>

# %% [markdown]
# <a id='intertemporal'></a>
# # Intertemporal exploration

# %% [markdown]
# Let us now turn to changes is the popularity of programming, scripting, and markup languages.
#
# <a id='question6'></a>
# ## Research Question No.6
#
# What programming, scripting, and markup languages are gaining popularity in 2020 compared to 2018 ?
# >
# >**LanguageWorkedWith**:
# >Which programming, scripting, and markup languages have you done extensive development work in over the past year?
# >
# >**LanguageDesireNextYear**: Which programming, scripting, and markup languages do you want to work in over the next year?

# %% [markdown]
# **First**, we would like to compare the shares of languages used by developers in 2018 and 2020.  We have already calculated the share of the 38 and the 25 programming languages for  **`df2018`** `LanguageWorkedWith` and **`df2020`** `LanguageWorkedWith` , respectively.

# %%
# turn a pandas series into a dataframe
props_df2018            = df2018_LanguageWorkedWith_share.to_frame(name='count')
props_df2018.index.name = 'language'
props_df2018            =  props_df2018.iloc[::-1] #  reverse the order

# turn a pandas series into a dataframe
props_df2020            = df2020_LanguageWorkedWith_share.to_frame(name='count')
props_df2020.index.name = 'language'
props_df2020            = props_df2020.iloc[::-1] #  reverse the order

# %% [markdown]
# Let us compare the share of each programming language common to both surveys.

# %%
print('\nWhich programming, scripting, and markup languages have you done \nextensive development work in over the past year?')
comp_df = pd.merge(props_df2018, props_df2020, left_index=True, right_index=True)
comp_df.columns = ['2018', '2020']
comp_df['Diff'] = comp_df['2020'] - comp_df['2018']
comp_df.style.bar(subset=['Diff'], align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# Which programming, scripting, and markup languages have you done
# extensive development work in over the past year?
# <style  type="text/css" >
#     #T_8ec8b102_5e40_11eb_924e_f44d30a6a9c7row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 22.7%, #d65f5f 22.7%, #d65f5f 39.0%, transparent 39.0%);
#         }    #T_8ec8b102_5e40_11eb_924e_f44d30a6a9c7row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 21.7%, #d65f5f 21.7%, #d65f5f 39.0%, transparent 39.0%);
#         }    #T_8ec8b102_5e40_11eb_924e_f44d30a6a9c7row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #d65f5f 0.0%, #d65f5f 39.0%, transparent 39.0%);
#         }    #T_8ec8b102_5e40_11eb_924e_f44d30a6a9c7row3_col2 {
# ...

# %% [markdown]
# Unfortunatly, there are only 22 languages shown here.
#
# Three language options from **`df2020`** `LanguageWorkedWith` are missing:
#
# - `[Bash/Shell/PowerShell]` ,
# - `[HTML/CSS]` and
# - `[Dart]` .
#
# There is some mismatch between the options in 2018 and 2020
# >**`df2018`** `LanguageWorkedWith` only listed the option `[Bash/Shell]` and not `[Bash/Shell/PowerShell]`
# >
# >**`df2018`** `LanguageWorkedWith` listed two seperate option `[HTML]` and `[CSS]`
# >
# >**`df2018`** `LanguageWorkedWith` does not include the option `[Dart]`
# >
# **Dart** is an object-oriented, class-based, garbage-collected language with C-style syntax. It is developed by Google and it was unveiled at the GOTO conference in Aarhus, Denmark, October 10–12, 2011.
# https://en.wikipedia.org/wiki/Dart_(programming_language)

# %% [markdown]
# Let us create a list of all the programming languages in the two surveys 2018 and 2020. This could easily be accomplished by the union of the two sets of languages for the 2018 and 2020 surveys.
#
# However, we want to ammend the list of languages by including **'Bash/Shell'** and **'HTML'** without a semi-colon at the end.
#
# >This way, we should find entries in both
# >
# >- **`df2018`** `LanguageWorkedWith` `[Bash/Shell]` and **`df2020`** `LanguageWorkedWith` `[Bash/Shell/Powershell]`
# >
# and
# >
# >- **`df2020`** `LanguageWorkedWith` `[HTML]` and **`df2020`** `LanguageWorkedWith` ``[HTML/CSS]``

# %%
programming_language = ["Assembly;", "Bash/Shell", "Bash/Shell/PowerShell;", "C;", "C#;", "C++;", 'CSS;','Clojure;','Cobol;',
                        'CoffeeScript;','Dart;','Delphi/Object Pascal;','Erlang;','F#;','Go;','Groovy;','HTML', 'HTML/CSS;',
                        'Hack;','Haskell;', 'Java;', 'JavaScript;','Julia;','Kotlin;','Lua;', 'Matlab;', 'Objective-C;','Ocaml;',
                        'PHP;', 'Perl;', 'Python;','R;','Ruby;','Rust;','SQL;','Scala;','Swift;', 'TypeScript;', 'VB.NET','VBA;',
                        'Visual Basic 6;']

# %% [markdown]
# We drop all rows with NANs in the variabel `[LanguageWorkedWith]` in both surveys.

# %%
df2018_clean = df2018_clean.dropna(subset=['LanguageWorkedWith'], axis=0)
df2020_clean = df2020_clean.dropna(subset=['LanguageWorkedWith'], axis=0) 
df2020_clean.shape
# Out:
# (57378, 126)

# %% [markdown]
# Helper function

# %%
def props_languages(df):
    '''
    INPUT 
        df - a dataframe holding the LanguageWorkedWith and LanguageDesireNextYear columns
        
    OUTPUT
        props_LanguageWorkedWith_df     - a dataframe with the share of each programming language worked with this year
        props_LanguageDesireNextYear_df - a dataframe with the share of each programming language desired next year
    '''
    
    LanguageWorkedWith = df['LanguageWorkedWith'].value_counts().reset_index()
    LanguageWorkedWith.rename(columns={'index': 'language', 'LanguageWorkedWith': 'count'}, inplace=True)
    LanguageWorkedWith_df = total_count(LanguageWorkedWith, 'language', 'count', programming_language)
    LanguageWorkedWith_df.set_index('language', inplace=True)
    
    LanguageDesireNextYear = df['LanguageDesireNextYear'].value_counts().reset_index()
    LanguageDesireNextYear.rename(columns={'index': 'language', 'LanguageDesireNextYear': 'count'}, inplace=True)
    LanguageDesireNextYear_df = total_count(LanguageDesireNextYear, 'language', 'count', programming_language)
    LanguageDesireNextYear_df.set_index('language', inplace=True)
    
    props_LanguageWorkedWith_df = LanguageWorkedWith_df/df.LanguageWorkedWith.shape[0]
    props_LanguageDesireNextYear_df = LanguageDesireNextYear_df/df.LanguageDesireNextYear.shape[0]
    
    return ( props_LanguageWorkedWith_df, props_LanguageDesireNextYear_df )

# %% [markdown]
# Let us run this helper function to create dataframes for the usage and the desirability of programming langauges.

# %%
props_df2018 , wanted_df2018 = props_languages(df2018_clean)
props_df2020 , wanted_df2020 = props_languages(df2020_clean)

# %% [markdown]
# However, we already know that there is a double counting error for the programming language **'C'** , because the helper function will not be able to destinguish **'C;'** from **'Objectice-C;'**. Therefore, we overwrite the results for **'C'** .

# %%
props_df2018.iloc[9] = df2018_LanguageWorkedWith_share['C;']

# %%
props_df2020.iloc[12] = df2020_LanguageWorkedWith_share['C;']

# %% [markdown]
# Let us create a nice looking table with the share of the 25 programming languages in 2018 and 2020.

# %%
print('\nWhich programming, scripting, and markup languages have you done \nextensive development work in over the past year?')
comp_df = pd.merge(props_df2018, props_df2020, left_index=True, right_index=True)
comp_df.columns = ['2018', '2020']
comp_df['Diff'] = comp_df['2020'] - comp_df['2018']
comp_df.style.bar(subset=['Diff'], align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# Which programming, scripting, and markup languages have you done
# extensive development work in over the past year?
# <style  type="text/css" >
#     #T_a91c2ba2_5e40_11eb_bf1d_f44d30a6a9c7row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 31.0%, #d65f5f 31.0%, #d65f5f 45.6%, transparent 45.6%);
#         }    #T_a91c2ba2_5e40_11eb_bf1d_f44d30a6a9c7row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 8.9%, #d65f5f 8.9%, #d65f5f 45.6%, transparent 45.6%);
#         }    #T_a91c2ba2_5e40_11eb_bf1d_f44d30a6a9c7row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 31.9%, #d65f5f 31.9%, #d65f5f 45.6%, transparent 45.6%);
#         }    #T_a91c2ba2_5e40_11eb_bf1d_f44d30a6a9c7row3_col2 {
# ...

# %% [markdown]
# </font><font color='green'>
#
#
# ## programming languages in use:
#
#
# >***[The 5 most popular languages in 2020]***
# >
# >However, they are losing market share compared to 2018
# >
# >>**(1)** `[JavaScript]` (-2.2 % ) remains the most popular programming language with developers
# >>
# >>**(2)** `[HTML]` (-5.4 %) and `[CSS]` (-2.0 %)
# >>
# >>**(3)** `[SQL]` (-2.3 % )
# >>
# >>**(4)** `[Java]` (-5.1 % )
# >>
# >>**(5)** `[Bash/Shell]` and `[Bash/Shell/PowerShell]` (-6.7 % )
# >>
#
# >***[Languages gaining popularity]***
# >
# >>**(6)** `[Python]` **(+5.3 % )**
# >>
# >>**(11)** `[TypeScript]` **(+8.0 %)**
# >>
# >>**(12)** `[Go]` **(+1.7 %)**
# >>
# >>**(15)** `[VBA]` **(+1.2 %)**
# >>
# >>**(16)** `[Kotlin]` **(+3.3 %)**
# >>
# >>**(24)** `[Rust]` **(+2.7 %)**
# >>
# >>**(24)** `[Julia]` **(+0.4 %)**
# >>

# %% [markdown]
# **Second**, we would like to compare the languages ***wanted*** by developers in 2018 and 2020.  We need to calculate the share of the 38 and the 25 programming languages for  **`df2018`** `LanguageDesireNextYear` and **`df2020`** `LanguageDesireNextYear` , respectively.
#
#
# >**LanguageDesireNextYear**: Which programming, scripting, and markup languages do you want to work in over the next year?

# %%
print('\nWhich of the following languages do you want\n to work in over the next year?')

comp_df = pd.merge(wanted_df2018, wanted_df2020, left_index=True, right_index=True)
comp_df.columns = ['2018', '2020']
comp_df['Diff'] = comp_df['2020'] - comp_df['2018']
comp_df.style.bar(subset=['Diff'], align='mid', color=['#d65f5a', '#5fba7d'])
# Out:
# Which of the following languages do you want
#  to work in over the next year?
# <style  type="text/css" >
#     #T_a926b282_5e40_11eb_b81c_f44d30a6a9c7row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 17.4%, #d65f5a 17.4%, #d65f5a 41.9%, transparent 41.9%);
#         }    #T_a926b282_5e40_11eb_b81c_f44d30a6a9c7row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 41.9%, #5fba7d 41.9%, #5fba7d 73.4%, transparent 73.4%);
#         }    #T_a926b282_5e40_11eb_b81c_f44d30a6a9c7row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 11.2%, #d65f5a 11.2%, #d65f5a 41.9%, transparent 41.9%);
#         }    #T_a926b282_5e40_11eb_b81c_f44d30a6a9c7row3_col2 {
#             width:  10em;
#              height:  80%;
# ...

# %% [markdown]
# </font><font color='green'>
#
#
# ## programming languages desired by developers:
#
#
# >***[The 5 most desired languages in 2020]***
# >
# >>**(1)** `[JavaScript]` (-3.5 % ) remains the most desired programming language with developers
# >>
# >>**(2)** `[Python]` **(+4.5 %)**
# >>
# >>**(3)** `[[HTML]` (-4.4 %) and `[CSS]` (-2.4 %)`
# >>
# >>**(4)** `[SQL]` (-1.0 % )
# >>
# >>**(5)** `[Java]` (-5.7 % )
# >>
# >***[Languages gaining popularity]***
# >>
# >>**(11)** `[TypeScript]` **(+8.3 %)**
# >>
# >>**(12)** `[Go]` **(+2.1 %)**
# >>
# >>**(16)** `[Kotlin]` **(+1.3 %)**
# >>
# >>**(24)** `[Rust]` **(+8.4 %)**
# >>
# >>**(24)** `[Julia]` **(+1.1 %)**
# >>
# >>**(15)** `[VBA]` **(+0.5 %)**
# >>

# %% [markdown]
# <a id='ml'></a>
# # Machine learning

# %% [markdown]
# We want to use a  machine learning model to find a linear relationship between the salaries of professional software developers in the USA and the variables of the 2020 survey.
#
# <a id='question7'></a>
# ## Research Question No.7
#
# What variables from the 2020 developer survey have a strong impact on the salaries of professional software developers in the USA?

# %% [markdown]
# Create a new pandas dataframe `df2020_proUSA` that consists of all the variables in **`df2020`** .
#
# Filter: take only observations where:
# - `MainBranch`  == `[I am a developer by profession]` and
# - `Country` == `[United States]`

# %%
df2020_proUSA = df2020_clean[df2020_clean.MainBranch == 'I am a developer by profession']
df2020_proUSA = df2020_proUSA[df2020_proUSA.Country  == 'United States']
df2020_proUSA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8885 entries, 7 to 64136
# Columns: 126 entries, Respondent to VBA;
# dtypes: bool(67), float64(7), int64(1), object(51)
# memory usage: 4.6+ MB

# %% [markdown]
# Next, we want to drop variables (i.e. columns) we don't want to consider when predicting the response (i.e. the salary of professional developers in the USA).
#
#
#
# First, drop four variables that probably do not have an impact on the response:
# >
# > ``SurveyEase`` (3 unique entries), ``SurveyLength`` (3), ``Trans`` (2), ``WelcomeChange`` (6)
# >
# Second, drop three variables that are determined already, because of our filter.
# >
# >``CurrencyDesc`` (1 == 'United States dollar'), ``CurrencySymbol`` (1 == 'USD' )  ``MainBranch`` (1 == 'I am a developer by profession' )
# >
#
# Third,  remove the 21 categorical variables from questions with multiple answer options to choose from, because they have a large number of unique entries.
# >
# >
# >``DatabaseDesireNextYear`` (3193 unique entries),  ``DatabaseWorkedWith`` (2808)
# >
# >``DevType`` (8269) *We have created Boolean variables (i.e. new columns) for each choice*
# >
# >``Ethnicity`` (208),  ``Gender`` (7) ,  ``JobFactors`` (230) ,  ``LanguageDesireNextYear`` (16243)
# >
# >``LanguageWorkedWith`` (14256) *We have created Boolean variables for each choice ()*
# >
# >``NEWCollabToolsDesireNextYear`` (1277)  ,  ``NEWCollabToolsWorkedWith`` (1153) ,  ``NEWJobHunt``  ,  ``NEWJobHuntResearch`` (63)
# >
# >``NEWPurchaseResearch``  ,  ``NEWSOSites``	(61) ,  ``NEWStuck`` (444)	,  ``MiscTechDesireNextYear`` (5216)
# >
# >``MiscTechWorkedWith`` (5216) *We have created Boolean variables (i.e. new columns) for each choice ()*
# >
# >``PlatformDesireNextYear``	(7471),  ``PlatformWorkedWith`` (6287),  ``Sexuality`` (14)  ,  ``WebframeDesireNextYear`` (3986)  , ``WebframeWorkedWith`` (3789)
# >

# %%
df2020_proUSA = df2020_proUSA.drop(['CurrencyDesc', 'CurrencySymbol', 'MainBranch', 'SurveyEase', 'SurveyLength', 
                                    'Trans', 'WelcomeChange','NEWPurchaseResearch','LanguageWorkedWith', 
                                    'LanguageDesireNextYear', 'MiscTechDesireNextYear', 'NEWCollabToolsDesireNextYear',
                                    'NEWCollabToolsWorkedWith','Sexuality','Ethnicity','Gender', 'JobFactors',
                                    'DatabaseDesireNextYear','DatabaseWorkedWith','Country', 
                                    'WebframeDesireNextYear','WebframeWorkedWith',
                                    'NEWJobHunt','NEWJobHuntResearch','NEWSOSites','NEWStuck',
                                    'PlatformDesireNextYear','PlatformWorkedWith'], axis=1)

# %%
df2020_proUSA.shape
# Out:
# (8885, 98)

# %% [markdown]
# Let us identify the remaining columns that are categorical in nature.  How many of the columns are considered categorical?  We use the reference [here](http://pbpython.com/categorical-encoding.html).

# %%
cat_df = df2020_proUSA.select_dtypes(include=['object']) # Subset to a dataframe only holding the categorical columns

# Print how many categorical columns are in the dataframe 
cat_df.shape[1]
# Out:
# 23

# %% [markdown]
# The columns that are categorical in nature are:

# %%
cat_vars    = df2020_proUSA.select_dtypes(include=['object']).copy().columns
categorical = list(cat_vars)
categorical
# Out:
# ['Hobbyist',
#  'CompFreq',
#  'EdLevel',
#  'Employment',
#  'JobSat',
#  'JobSeek',
#  'NEWDevOps',
#  'NEWDevOpsImpt',
#  'NEWEdImpt',
#  'NEWLearn',
#  'NEWOffTopic',
#  'NEWOnboardGood',
#  'NEWOtherComms',
#  'NEWOvertime',
#  'NEWPurpleLink',
#  'OpSys',
#  'OrgSize',
#  'PurchaseWhat',
#  'SOAccount',
#  'SOComm',
#  'SOPartFreq',
#  'SOVisitFreq',
#  'UndergradMajor']

# %% [markdown]
# There are 23 categorial variables (i.e. columns) with a total of **112 unique entries.**
#
# `Hobbyist` (2 unique entries),
# `CompFreq` (3),
# `EdLevel` (9),
# `Employment` (7),
# `JobSat` (5) ,
# `JobSeek`(3),
# `NEWDevOps`(3),
# `NEWDevOpsImpt` (5),
# `NEWEdImpt` (5),
# `NEWLearn` (4),
# `NEWOffTopic` (3),
# `NEWOnboardGood` (3),
# `NEWOtherComms` (2),
# `NEWOvertime` (5),
# `NEWPurpleLink` (4),
# `OpSys` (4),
# `OrgSize`(9),
# `PurchaseWhat` (3),
# `SOAccount` (3),
# `SOComm` (6),
# `SOPartFreq` (6),
# `SOVisitFreq`(6),
# `UndergradMajor` (12),

# %% [markdown]
# The number of columns with more than half of the column missing

# %%
np.sum(np.sum(df2020_proUSA.isnull())/df2020_proUSA.shape[0] > .5)
# Out:
# 0

# %%
# pandas - use boolean Series to delete DataFrame columns with more than 25% missing values
s = (np.sum(df2020_proUSA.isnull())/df2020_proUSA.shape[0] > .25)
df2020_proUSA[df2020_proUSA.columns[~s]]
df2020_proUSA.shape
# Out:
# (8885, 98)

# %% [markdown]
# The columns that are numerical in nature:

# %%
num_vars  = df2020_proUSA.select_dtypes(include=['float', 'int']).columns
numerical = list(num_vars)
numerical
# Out:
# ['Age',
#  'Age1stCode',
#  'CompTotal',
#  'ConvertedComp',
#  'WorkWeekHrs',
#  'YearsCode',
#  'YearsCodePro']

# %%
bool_df = df2020_proUSA.select_dtypes(include=['bool']) # Subset to a dataframe only holding the boolean columns

# Print how many categorical columns are in the dataframe 
bool_df.shape[1]
# Out:
# 67

# %% [markdown]
# The 67 columns that are boolean in nature are:

# %%
bool_vars  = df2020_proUSA.select_dtypes(include=['bool']).columns
boolean = list(bool_vars)
boolean
# Out:
# ['Developer_mobile',
#  'Developer_embedded_applications_or_devices',
#  'Developer_backend',
#  'Marketing_or_sales_professional',
#  'Developer_fullstack',
#  'Engineering_manager',
#  'Data_scientist_or_machine_learning_specialist',
#  'Academic_researcher',
#  'Developer_desktop_or_enterprise_applications',
#  'Developer_QA_or_test',
#  'Scientist',
#  'Designer',
#  'Product_manager',
#  'Data_or_business_analyst',
#  'Senior_executive_VP',
#  'Engineer_site_reliability',
#  'Developer_game_or_graphics',
#  'System_administrator',
#  'DevOps_specialist',
#  'Engineer_data',
#  'Database_administrator',
#  'Educator',
#  'Developer_frontend',
#  'React Native',
#  'Cordova',
#  'Torch/PyTorch',
#  'Unreal Engine',
#  'Pandas',
#  'Teraform',
#  'Node.js',
#  'Ansible',
#  'Unity 3D',
#  'Chef',
#  'Hadoop',
#  'Apache Spark',
#  'Puppet',
#  'Xamarin',
#  '.NET Core',
#  'Flutter',
#  'TensorFlow',
#  'Keras',
#  '.NET',
#  'Assembly;',
#  'Bash/Shell/PowerShell;',
#  'C;',
# ...

# %% [markdown]
# We define a helper function to clean the input data and to create the matrix **`X`** and the response vector **`y`** needed for machine learning.
#
# Furthermore, it should create **dummy columns** for the categorical variables in **`df2020_proUSA`**, droping the original columns.

# %%
def clean_data(df):
    '''
    INPUT
    df - pandas dataframe 
    
    OUTPUT
    X - A matrix holding all of the variables you want to consider when predicting the response
    y - the corresponding response vector
    
    Perform to obtain the correct X and y objects
    This function cleans df using the following steps to produce X and y:
    1. Drop all the rows with no salaries
    2. Create X as all the columns that are not the Salary column
    3. Create y as the Salary column
    4. Drop the Salary, Respondent, and the ExpectedSalary columns from X
    5. For each numeric variable in X, fill the NANs with the mean value of the column.
    6. Create dummy columns for all the categorical variables in X, drop the original columns
    
    This function cleans the input data for machine learning.
    '''
    
    # Drop rows with missing salary values
    df = df.dropna(subset=['ConvertedComp'], axis=0)
    y = df['ConvertedComp']
    
    #Drop respondent and salary columns
    df = df.drop(['Respondent', 'CompTotal', 'ConvertedComp'], axis=1)
    
    # Fill numeric columns with the mean
    num_vars = df.select_dtypes(include=['float', 'int']).columns
    for col in num_vars:
        df[col].fillna((df[col].mean()), inplace=True)
        
    # Dummy the categorical variables
    cat_vars = df.select_dtypes(include=['object']).copy().columns
    for var in  cat_vars:
        # for each cat add dummy var, drop original column
        df = pd.concat([df.drop(var, axis=1), pd.get_dummies(df[var], prefix=var, prefix_sep='_', drop_first=True)], axis=1)
    
    X = df
    return X, y

# %%
#Use the function to create X and y
X, y = clean_data(df2020_proUSA)

# %% [markdown]
# ### Imput matrix

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7096 entries, 7 to 64122
# Columns: 157 entries, Age to UndergradMajor_Web development or web design
# dtypes: bool(67), float64(5), uint8(85)
# memory usage: 1.4 MB

# %%
X.describe()
# Out:
#                Age   Age1stCode  WorkWeekHrs    YearsCode  YearsCodePro  \
# count  7096.000000  7096.000000  7096.000000  7096.000000   7096.000000
# mean     34.105685    14.754341    41.561055    16.351936     10.294076
# std       9.209009     5.317735     7.445509    10.688542      9.096343
# min       1.000000     4.000000     3.000000     0.500000      0.500000
# 25%      27.000000    12.000000    40.000000     8.000000      3.000000
# 50%      33.000000    14.000000    40.000000    14.000000      7.000000
# 75%      38.000000    17.000000    45.000000    22.000000     15.000000
# max      99.000000    50.000000   120.000000    50.000000     50.000000
#
#        Hobbyist_Yes  CompFreq_Weekly  CompFreq_Yearly  \
# count   7096.000000      7096.000000      7096.000000
# mean       0.760428         0.046082         0.906708
# std        0.426852         0.209678         0.290862
# min        0.000000         0.000000         0.000000
# ...

# %% [markdown]
# ### Response vector
#
# Let us look at the distribution of the saleries for professional developers in the USA.

# %%
sns.set(context='notebook', style='whitegrid', palette='deep', font='sans-serif', font_scale=1, rc=None)
plt.figure(figsize=[8, 5])
#sns.boxplot(df2020_clean['CompTotal'])
sns.boxplot(y)
plt.xticks(rotation=0, fontsize=15)
plt.yticks(rotation=0, fontsize=15)
plt.xlim([0, 300000])
plt.title("Developers USA (2020 Survey)\n Total compensation annual (in USD)");
plt.show()

# %%
def linear_mod(X, y, test_size=.3, rand_state=42):
    '''
    INPUT:
    X - a cleaned X matrix (dummy and mean imputation)
    y - a cleaned response (without NANs)
    test_size - a float between [0,1] about what proportion of data should be in the test dataset
    rand_state - an int that is provided as the random state for splitting the data into training and test

    OUTPUT:
    test_score - float - r2 score on the test data
    train_score - float - r2 score on the train data
    lm_model - model object from sklearn
    X_train, X_test, y_train, y_test - output from sklearn train test split used for optimal model

    This function provides the output of a linear machine learning model using the python scikit-learn library
    '''
    
    #Split into train and test
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=rand_state)

    lm_model = LinearRegression(normalize=True) # Instantiate
    lm_model.fit(X_train, y_train) #Fit

    #Predict using your model
    y_test_preds = lm_model.predict(X_test)
    y_train_preds = lm_model.predict(X_train)

    #Score using your model
    test_score = r2_score(y_test, y_test_preds)
    train_score = r2_score(y_train, y_train_preds)

    return test_score, train_score, lm_model, X_train, X_test, y_train, y_test

# %% [markdown]
# Run the ml function with the above dataset

# %%
test_score, train_score, lm_model, X_train, X_test, y_train, y_test = linear_mod(X, y)

# %% [markdown]
# What is the training score?

# %%
train_score
# Out:
# 0.5482961857230606

# %% [markdown]
# What is the test score?

# %%
test_score
# Out:
# 0.5306622337278202

# %% [markdown]
# The ml model explains about half of the volatility in the response variable. It does not overfit, because training score and test score are very close to each other.

# %% [markdown]
# ### The coefficients of the linear model

# %% [markdown]
# The default penalty on coefficients using linear regression in sklearn is a ridge (also known as an L2) penalty.  Because of this penalty, and that all the variables were normalized, we can look at the size of the coefficients in the model as an indication of the impact of each variable on the salary.  The larger the coefficient, the larger the expected impact on salary.
#
# We use the space below to take a look at the coefficients.

# %%
def coef_weights(coefficients, X_train):
    '''
    INPUT:
    coefficients - the coefficients of the linear model 
    X_train - the training data, so the column names can be used
    OUTPUT:
    coefs_df - a dataframe holding the coefficient, estimate, and abs(estimate)
    
    Provides a dataframe that can be used to understand the most influential coefficients
    in a linear model by providing the coefficient estimates along with the name of the 
    variable attached to the coefficient.
    '''
    coefs_df = pd.DataFrame()
    coefs_df['est_int'] = X_train.columns
    coefs_df['coefs'] = lm_model.coef_
    coefs_df['abs_coefs'] = np.abs(lm_model.coef_)
    coefs_df = coefs_df.sort_values('abs_coefs', ascending=False)
    return coefs_df

#Use the function
coef_df = coef_weights(lm_model.coef_, X_train).reset_index(drop=True)

#A quick look at the top results
coef_df.head(10)
# Out:
#                                              est_int          coefs  \
# 0                                    CompFreq_Yearly -777126.539048
# 1                      Employment_Employed part-time -422993.372816
# 2                                    CompFreq_Weekly  298454.104957
# 3  SOVisitFreq_I have never visited Stack Overflo... -254994.401107
# 4         EdLevel_Professional degree (JD, MD, etc.)  195647.380144
# 5  Employment_Independent contractor, freelancer,... -165203.215789
# 6                  EdLevel_Primary/elementary school  111587.649785
# 7  OrgSize_Just me - I am a freelancer, sole prop... -108907.330076
# 8  EdLevel_Other doctoral degree (Ph.D., Ed.D., e...  100339.621381
# 9  UndergradMajor_A health science (such as nursi...  -83735.247516
#
#        abs_coefs
# 0  777126.539048
# 1  422993.372816
# 2  298454.104957
# 3  254994.401107
# 4  195647.380144
# 5  165203.215789
# 6  111587.649785
# 7  108907.330076
# 8  100339.621381
# 9   83735.247516

# %%
coef_df.tail()
# Out:
#                                              est_int       coefs   abs_coefs
# 152                                       Age1stCode -560.579130  560.579130
# 153  SOVisitFreq_Less than once per month or monthly  547.363191  547.363191
# 154                                           Pandas  458.393997  458.393997
# 155                               NEWOnboardGood_Yes  408.122972  408.122972
# 156                                              Age  113.981320  113.981320

# %% [markdown]
# ### Ranking of coefficients
#
# The index of coefficients **`coef_df`** runs from the coefficient with the highest absolute impact on the salary to the coefficient with the lowest impact.
#
# For example:
# >Coefficient No **(1)** *``[Employment_Employed part-time]``* was mapped from the categorical variable ``Employment`` and the answer option ``[Employed part-time]``. It has the second highest impact on the response vector, albeit with a negative sign.
#
# >Interpretation: Developers who are part-time employed tend to have lower salaries.
#
# However, other coefficients with a high (positive) impact are more difficult to interpret.
# >Coefficient No. **(6)** *``[EdLevel_Primary/elementary school]``* is the mapping of answer option ``[elementary school]`` to the question: "Which of the following best describes the highest level of formal education that you have completed?" It is counterintuative to assume that US developers without secondary school and college/university education earn the highest salaries. The respondants who ticked this option might have provided inflated salary figures.

# %% [markdown]
# Let us look at the ranking of developer roles.

# %%
DevType = ["DevType", "Academic_researcher" , "Scientist" ,"Data_or_business_analyst" ,
           "Data_scientist_or_machine_learning_specialist",
           "Developer_frontend", "Developer_backend", "Developer_fullstack" , 
           "Developer_QA_or_test" , "Developer_desktop_or_enterprise_applications" ,  
           "Developer_game_or_graphics" , "Engineer_site_reliability" , "System_administrator" ,  
           "DevOps_specialist" , "Developer_embedded_applications_or_devices"  , 
           "Developer_mobile" , "Database_administrator" , "Engineer_data" , "Engineering_manager" ,        
           "Educator" , "Marketing_or_sales_professional" ,  "Designer" , "Product_manager", "Senior_executive_VP"]
           
coef_df[coef_df['est_int'].isin(DevType)] # we filter for rows that contain an element of the list DevType.
# Out:
#                                            est_int         coefs     abs_coefs
# 12                             Senior_executive_VP  70227.942397  70227.942397
# 14                             Academic_researcher -67755.690317  67755.690317
# 21                                        Educator  47407.602117  47407.602117
# 23                                       Scientist -45797.958721  45797.958721
# 25                                 Product_manager  42472.280256  42472.280256
# 33                       Engineer_site_reliability  32770.124007  32770.124007
# 36                                        Designer -29647.906758  29647.906758
# 39                            Developer_QA_or_test -28586.871323  28586.871323
# 47   Data_scientist_or_machine_learning_specialist  25412.707235  25412.707235
# 70                              Developer_frontend  16848.282859  16848.282859
# 78                        Data_or_business_analyst  15402.608841  15402.608841
# ...

# %% [markdown]
# </font><font color='green'>
#
# Ranking
#
# >**(12)** **``Senior_executive_VP``** have the highest (positive) impact on the reponse vector of all developer roles  (i.e. tend to have high salaries)
# >
# >**(14)** **``Academic_researcher``** have the second highest (but negative) impact on the reponse vector (i.e. tend to have lower salaries)
# >
# >**(23)** **``Scientist``** have the fourth highest (but negative) impact on the reponse vector (i.e. tend to have lower salaries)
# >
# >**(47)**  **``Data_scientist_or_machine_learning_specialist``**  have the ninth highest (and positive) impact of all developer roles.
# >
# >**(78)**  **``Data_or_business_analyst``**  have the 11th highest (and positive) impact of all developer roles.
# >
# >**(150)**  **``Developer_backend``**  have the lowest (but positive) impact of all developer roles and one of the lowest impact of all coefficients.
#
#
# Interpretation:
# >- Professional developers who perform the roles of **``Senior executive/VP``** have higher expected salaries than developers with other roles. The higher salary forecast might reflect the seniority associated with this job title.
# >- **``Academic researcher``** and **``Scientists``** tend to earn lower salaries, presumably because they do not only work for monetary compensation but might still work on their Ph.D. degrees or have prestigious but temporary PostDoc positions.
# >- The developer role **``Data scientist / machine learning specialist``** has a ***moderately strong impact*** on the salary expectation.
# >- The developer role **``Data / business analyst``** has a ***moderate impact*** on the response variabel.
# >
# >- The developer role **``Developer backend``** has a ***weak impact*** on the salary.
#
# </font><font color='black'>

# %% [markdown]
# Let us look at the impact of programming languages used by developers:

# %%
coef_df[coef_df['est_int'].isin(programming_language2020)]
# Out:
#                     est_int         coefs     abs_coefs
# 19                    Dart; -49802.394320  49802.394320
# 22                 Haskell; -46925.848562  46925.848562
# 38             Objective-C;  28716.679953  28716.679953
# 40                   Julia;  28535.990101  28535.990101
# 42                      Go;  27345.663849  27345.663849
# 46                   Scala;  25641.600163  25641.600163
# 48                    Rust;  25077.361922  25077.361922
# 56                  Python; -21684.844157  21684.844157
# 57                  Kotlin;  21475.612048  21475.612048
# 59              JavaScript; -19778.111940  19778.111940
# 65                   Swift; -18549.996647  18549.996647
# 68                     VBA;  17258.056280  17258.056280
# 75                    Ruby;  15906.116897  15906.116897
# 79   Bash/Shell/PowerShell;  15262.416589  15262.416589
# 80                     C++;  14905.995285  14905.995285
# 82                    Java;  13864.764817  13864.764817
# ...

# %% [markdown]
# </font><font color='green'>
#
# Niche programming languages have a strong impact on salary expectations:
#
# >**(19)** **``Dart``** , **(22)** **``Haskell``** , **(38)**  **``Objective-C``**  ,  **(40)** **``Julia``**   ,  **(42)**  **``Go``**  , **(46)** **``Scala``** and **(48)** **``Rust``**
# have the highest impact on the reponse vector .
#
# Programming Languages popular with Data Scientists have moderate to weak impacts on salary expectations:
#
# >**(56)** **``Python``** has a ***moderately strong (negative) impact*** on the salary expectation.
# >
# >**(79)** **``Bash/Shell/PowerShell``** has a ***moderate (positive) impact*** on the salary expectation.
# >
# >**(115)** **``SQL``**  and  **(143)** **``R``** have a ***weak impact*** on salary.
#
# Programming Languages for Web development have moderate to weak impacts on salary expectations:
#
# >**(59)** **``JavaScript``** has a ***moderately strong (negative) impact*** on the salary expectation.
#
# >**(126)** **``TypeScript``**  and  **(127)** **``HTML/CSS``** have a ***weak impact*** on salary.
#
# </font><font color='black'>

# %% [markdown]
# Let us now look at other technologies used by developers:

# %% [markdown]
# **MiscTechWorkedWith**:
#
# >Which other frameworks, libraries, and tools have you done extensive development work in over the past year?

# %%
coef_df[coef_df['est_int'].isin(MiscTechWorkedWith)]
# Out:
#            est_int         coefs     abs_coefs
# 30         Flutter  37309.641384  37309.641384
# 34         Ansible -30936.006354  30936.006354
# 41          Puppet  28161.662112  28161.662112
# 43   Torch/PyTorch  26463.764627  26463.764627
# 44           Keras  26246.510494  26246.510494
# 55       .NET Core  22107.817386  22107.817386
# 60            Chef  19652.296622  19652.296622
# 67         Xamarin  17891.388825  17891.388825
# 77         Cordova -15499.829587  15499.829587
# 86        Teraform -13242.732217  13242.732217
# 105  Unreal Engine  -8305.935705   8305.935705
# 114   Apache Spark  -6659.753295   6659.753295
# 116   React Native  -6420.857752   6420.857752
# 122        Node.js  -5791.950843   5791.950843
# 129         Hadoop   4214.037499   4214.037499
# 135           .NET  -3505.484534   3505.484534
# 140     TensorFlow   2774.818107   2774.818107
# 142       Unity 3D  -2205.574845   2205.574845
# 154         Pandas    458.393997    458.393997

# %% [markdown]
# </font><font color='green'>
#
#
# Maschine learning tools:
#
# >**(43)** **``Torch/PyTorch``** and **(44)** **``Keras``** have a ***moderately strong (positive) impact*** on the salary expectation.
# >
# >**(140)**  **``TensorFlow``**  has the weak impact on the reponse vector .
#
# Big Data tools:
#
# >**(114)** **``Apache Spark``** and **(129)** **``Hadoop``**  have a ***moderate impact*** on the salary expectation.
#
# Data Science tools:
#
# >**(154)** **``Pandas``** has a ***very weak impact*** on the salary expectation.
#
# </font><font color='black'>

# %%
coef_df[coef_df['est_int'].isin(numerical)]
# Out:
#           est_int        coefs    abs_coefs
# 124   WorkWeekHrs  4860.111651  4860.111651
# 137  YearsCodePro  3073.995603  3073.995603
# 144     YearsCode -1385.700569  1385.700569
# 152    Age1stCode  -560.579130   560.579130
# 156           Age   113.981320   113.981320

# %% [markdown]
# </font><font color='green'>
#
# Surprisingly, numerical variables have only a weak impact on the response variable.

# %% [markdown]
# <a id='conclusion'></a>
# # Conclusion

# %% [markdown]
# The StackOverflow Developer Survey 2020 contains 61 questions (i.e. variables) and 64461 users from all over the world took part. We have used the answers (i.e. observations) from professional developers in the USA (subset of 7096 observations) to train a linear machine learning model with **sklearn**. We have used 5 numerical variables like work experience (in years) and we have mapped 26 of the survey's categorical variables as input for the ml model. It accounts for the variation (dispersion) of 50% of the salaries of professional developers in the USA. The **r² score** is above 0.5 for both the train data (70% of observations) and the test data (30% of observations).
#
# Next, we have analysed the coefficients of ml model. The default penalty on coefficients using linear regression in sklearn is a ridge (also known as an L2) penalty.  Because of this penalty, and that all the variables were normalized, we can look at the size of the coefficients in the model as an indication of the impact of each variable on the salary.  The larger the coefficient, the larger the expected impact on salary.
#
# We have analysed the impact of developer roles, programmming languages and of other technologies developers have used over the past year. Professional developers who perform the role of **Senior executive/VP** have the highest expected salary of all developer types, while **Developer backend** have the lowest.  The developer role **Data scientist / machine learning specialist** has a moderately strong impact on the response variable. In contrast, the role of **Data / business analyst** has only a ***moderate impact*** on the response variabel.
#
# Niche programming languages like **Dart** or **Julia** have a strong impact on salary expectations. The two programming languages most popular with Data scientists / machine learning specialists, **Python** and **R** , have a moderately strong and a weak impact on the response variable, respectively. Knowledge of command line Interface languages **Bash/Shell/PowerShell** has a moderate impact and proficiency in the relational database language **SQL** has only a weak impact on forecasted salaries.
#
# Using the machine the learning tools **Torch/PyTorch** and **Keras** have a moderately strong impact on expected salaries, while using the tools **TensorFlow** and **Pandas** only have a weak impact on the reponse variable. However, proficiency in the Big Data tools **Apache Spark** and **Hadoop** have a moderate impact on expected salaries.
